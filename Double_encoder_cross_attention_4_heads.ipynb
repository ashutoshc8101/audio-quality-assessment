# %%
#run
# !pip install spafe pandas tensorflow seaborn opencv-python tqdm librosa
# Out:
# Requirement already satisfied: spafe in /home/ashutosh/anaconda3/lib/python3.11/site-packages (0.3.2)
# Requirement already satisfied: pandas in /home/ashutosh/anaconda3/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: tensorflow in /home/ashutosh/anaconda3/lib/python3.11/site-packages (2.14.0)
# Requirement already satisfied: seaborn in /home/ashutosh/anaconda3/lib/python3.11/site-packages (0.12.2)
# Requirement already satisfied: opencv-python in /home/ashutosh/anaconda3/lib/python3.11/site-packages (4.8.1.78)
# Requirement already satisfied: tqdm in /home/ashutosh/anaconda3/lib/python3.11/site-packages (4.65.0)
# Requirement already satisfied: librosa in /home/ashutosh/anaconda3/lib/python3.11/site-packages (0.10.1)
# Requirement already satisfied: numpy>=1.21 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from spafe) (1.24.3)
# Requirement already satisfied: scipy>=1.7.3 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from spafe) (1.11.1)
# Requirement already satisfied: typing-extensions in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from spafe) (4.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: absl-py>=1.0.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (4.24.4)
# Requirement already satisfied: setuptools in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.59.0)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: audioread>=2.1.9 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from librosa) (1.3.0)
# Requirement already satisfied: joblib>=0.14 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from librosa) (1.2.0)
# Requirement already satisfied: decorator>=4.3.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from librosa) (0.57.1)
# Requirement already satisfied: soundfile>=0.12.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from librosa) (1.7.0)
# Requirement already satisfied: soxr>=0.3.2 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from librosa) (0.3.7)
# Requirement already satisfied: lazy-loader>=0.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from librosa) (0.2)
# Requirement already satisfied: msgpack>=1.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from librosa) (1.0.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.38.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from numba>=0.51.0->librosa) (0.40.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from pooch>=1.0->librosa) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from pooch>=1.0->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.23.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.2.3)
# Requirement already satisfied: pycparser in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (3.2.2)

# %%
#run
import pandas as pd
import os
import librosa
import librosa.display
import numpy as np
import IPython.display as ipd
import matplotlib.pyplot as plt
# %matplotlib inline

from collections import defaultdict
from spafe.utils import vis
from spafe.features.lfcc import lfcc

# %%
#run
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from sklearn import metrics
from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

# %%
#run
import pandas as pd
import numpy as np
import os.path
import matplotlib.pyplot as plt
import seaborn as sns
import gc

from PIL import Image

# %matplotlib inline
from tensorflow import keras
from tensorflow.keras.applications import ResNet50,ResNet101
import cv2
from tqdm import tqdm
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import backend as K
from tensorflow.keras import applications
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing import image
from sklearn.model_selection import StratifiedKFold , KFold ,RepeatedKFold
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

# %%
#run
def scaled_dot_product_attention(query, key, value, mask):
  matmul_qk = tf.matmul(query, key, transpose_b=True)

  depth = tf.cast(tf.shape(key)[-1], tf.float32)
  logits = matmul_qk / tf.math.sqrt(depth)

  # add the mask zero out padding tokens.
  if mask is not None:
    logits += (mask * -1e9)

  attention_weights = tf.nn.softmax(logits, axis=-1)

  return tf.matmul(attention_weights, value)

# %%
#run
# This allows to the transformer to know where there is real data and where it is padded
def create_padding_mask(seq):
  seq = tf.cast(tf.math.equal(seq, 0), tf.float32)

  # add extra dimensions to add the padding
  # to the attention logits.
  return seq[:, tf.newaxis, tf.newaxis, :]  # (batch_size, 1, 1, seq_len)

# %%
#run
class MultiHeadAttention(tf.keras.layers.Layer):

  def __init__(self, d_model, num_heads, name="multi_head_attention"):
    super(MultiHeadAttention, self).__init__(name=name)
    self.num_heads = num_heads
    self.d_model = d_model

    assert d_model % self.num_heads == 0

    self.depth = d_model // self.num_heads

    self.query_dense = tf.keras.layers.Dense(units=d_model)
    self.key_dense = tf.keras.layers.Dense(units=d_model)
    self.value_dense = tf.keras.layers.Dense(units=d_model)

    self.dense = tf.keras.layers.Dense(units=d_model)

  def split_heads(self, inputs, batch_size):
    inputs = tf.reshape(
        inputs, shape=(batch_size, -1, self.num_heads, self.depth))
    return tf.transpose(inputs, perm=[0, 2, 1, 3])

  def call(self, inputs):
    query, key, value, mask = inputs['query'], inputs['key'], inputs[
        'value'], inputs['mask']
    batch_size = tf.shape(query)[0]

    # linear layers
    query = self.query_dense(query)
    key = self.key_dense(key)
    value = self.value_dense(value)

    # split heads
    query = self.split_heads(query, batch_size)
    key = self.split_heads(key, batch_size)
    value = self.split_heads(value, batch_size)

    scaled_attention = scaled_dot_product_attention(query, key, value, mask)

    scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])

    concat_attention = tf.reshape(scaled_attention,
                                  (batch_size, -1, self.d_model))

    outputs = self.dense(concat_attention)

    return outputs

# %%
#run
class PositionalEncoding(tf.keras.layers.Layer):

  def __init__(self, position, d_model):
    super(PositionalEncoding, self).__init__()
    self.pos_encoding = self.positional_encoding(position, d_model)

  def get_angles(self, position, i, d_model):
    angles = 1 / tf.pow(10000, (2 * (i // 2)) / tf.cast(d_model, tf.float32))
    return position * angles

  def positional_encoding(self, position, d_model):
    angle_rads = self.get_angles(
        position=tf.range(position, dtype=tf.float32)[:, tf.newaxis],
        i=tf.range(d_model, dtype=tf.float32)[tf.newaxis, :],
        d_model=d_model)
    # apply sin to even index in the array
    sines = tf.math.sin(angle_rads[:, 0::2])
    # apply cos to odd index in the array
    cosines = tf.math.cos(angle_rads[:, 1::2])

    pos_encoding = tf.concat([sines, cosines], axis=-1)
    pos_encoding = pos_encoding[tf.newaxis, ...]
    return tf.cast(pos_encoding, tf.float32)

  def call(self, inputs):
    return inputs + self.pos_encoding[:, :tf.shape(inputs)[1], :]

# %%
#run
def encoder_layer(units, d_model, num_heads, dropout,name="encoder_layer"):
  inputs = tf.keras.Input(shape=(None,d_model ), name="inputs")
  padding_mask = tf.keras.Input(shape=(1, 1, None), name="padding_mask")
  print(padding_mask)

  attention1 = MultiHeadAttention(
      d_model, num_heads, name="attention1")({
          'query': inputs,
          'key': inputs,
          'value': inputs,
          'mask': padding_mask
      })
  attention1 = tf.keras.layers.Dropout(rate=dropout)(attention1)
  attention1 = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(inputs + attention1)
    
  attention2 = MultiHeadAttention(
      d_model, num_heads, name="attention2")({
          'query': inputs,
          'key': inputs,
          'value': inputs,
          'mask': padding_mask
      })
  attention2 = tf.keras.layers.Dropout(rate=dropout)(attention2)
  attention2 = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(inputs + attention2)

  attention3 = MultiHeadAttention(
      d_model, num_heads, name="attention3")({
          'query': attention1,
          'key': attention2,
          'value': attention1,
          'mask': padding_mask
      })
  attention3 = tf.keras.layers.Dropout(rate=dropout)(attention3)
  attention3 = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(inputs + attention3)
  outputs = tf.keras.layers.Dense(units=units, activation='relu')(attention3)
  outputs = tf.keras.layers.Dense(units=d_model)(outputs)
  outputs = tf.keras.layers.Dropout(rate=dropout)(outputs)
  # outputs = tf.keras.layers.LayerNormalization(
  #     epsilon=1e-6)(attention3 + outputs)
  outputs = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(attention3)

  return tf.keras.Model(
      inputs=[inputs, padding_mask], outputs=outputs, name=name)

# %%
#run
def encoder(time_steps,
            num_layers,
            units,
            d_model,
            num_heads,
            dropout,
            projection,
            name="encoder"):
  inputs = tf.keras.Input(shape=(None,d_model), name="inputs")
  padding_mask = tf.keras.Input(shape=(1, 1, None), name="padding_mask")

  if projection=='linear':
    ## We implement a linear projection based on Very Deep Self-Attention Networks for End-to-End Speech Recognition. Retrieved from https://arxiv.org/abs/1904.13377
    projection=tf.keras.layers.Dense( d_model,use_bias=True, activation='linear')(inputs)
    print('linear')

  else:
    projection=tf.identity(inputs)
    print('none')

  projection *= tf.math.sqrt(tf.cast(d_model, tf.float32))
  projection = PositionalEncoding(time_steps, d_model)(projection)

  outputs = tf.keras.layers.Dropout(rate=dropout)(projection)

  for i in range(num_layers):
    outputs = encoder_layer(
        units=units,
        d_model=d_model,
        num_heads=num_heads,
        dropout=dropout,
        name="encoder_layer_{}".format(i),
    )([outputs, padding_mask])

  return tf.keras.Model(
      inputs=[inputs, padding_mask], outputs=outputs, name=name)

# %%
#run
def transformer(time_steps,
                num_layers,
                units,
                d_model,
                num_heads,
                dropout,
                output_size,
                projection,
                name="transformer"):
  inputs = tf.keras.Input(shape=(None,d_model), name="inputs")

  enc_padding_mask = tf.keras.layers.Lambda(
      create_padding_mask, output_shape=(1, 1, None),
      name='enc_padding_mask')(tf.dtypes.cast(

      #Like our input has a dimension of length X d_model but the masking is applied to a vector
      # We get the sum for each row and result is a vector. So, if result is 0 it is because in that position was masked
      tf.math.reduce_sum(
      inputs,
      axis=2,
      keepdims=False,
      name=None
  ), tf.int32))

  enc_outputs = encoder(
      time_steps=time_steps,
      num_layers=num_layers,
      units=units,
      d_model=d_model,
      num_heads=num_heads,
      dropout=dropout,
      projection=projection,
      name='encoder'
  )(inputs=[inputs, enc_padding_mask])

  #We reshape for feeding our FC in the next step
  outputs=tf.reshape(enc_outputs,(-1,time_steps*d_model))

  #We predict our class
  outputs = tf.keras.layers.Dense(units=output_size,use_bias=True, name="outputs")(outputs)

  return tf.keras.Model(inputs=[inputs], outputs=outputs, name='audio_class')

# %%
#run
# num_batch_size = 32
# num_epochs = 500
# N_SPLIT = 10
# num_labels=5
# num_classes=6

# %%
#ajit
# df = pd.read_csv('/content/drive/MyDrive/DatabaseDistorted/final_tii_all_finaldata/features/2075_concatenate5_spectral2.csv')
# dm
# df = pd.read_csv('./DatabaseDistorted/final_tii_all_finaldata/features/2075_concatenate_dm.csv')
df = pd.read_csv('./features/original.csv')


# df = pd.read_csv('/content/drive/MyDrive/DatabaseDistorted/final_tii_all_finaldata/features/melspectogram_mean_newdm_2075.csv')
# df = pd.read_csv('/content/drive/MyDrive/DatabaseDistorted/final_tii_all_finaldata/features/chroma_cqt_simple_mean_newdm_2075.csv')
# df = pd.read_csv('/content/drive/MyDrive/DatabaseDistorted/final_tii_all_finaldata/features/mfcc_simple_mean_newdm_2075.csv')
# df = pd.read_csv('/content/drive/MyDrive/DatabaseDistorted/final_tii_all_finaldata/features/spectral_centroid_meandm_2075_200.csv')

df = df.drop(['Unnamed: 0'], axis = 1)
df = df.dropna()
df.shape
# Out:
# (2075, 181)

# %%
np.random.seed(42)
siz=415
df_read = df.copy()
df1 = df_read.sample(siz)
df_read = df_read.drop(df1.index)
df2 = df_read.sample(siz)
df_read = df_read.drop(df2.index)
df3 = df_read.sample(siz)
df_read = df_read.drop(df3.index)
df4 = df_read.sample(siz)
df_read = df_read.drop(df4.index)
df5 = df_read.copy()

print(df1.shape)
print(df2.shape)
print(df3.shape)
print(df4.shape)
print(df5.shape)
# Out:
# (415, 181)
# (415, 181)
# (415, 181)
# (415, 181)
# (415, 181)

# %%
q = list(df1.index)+list(df2.index)+list(df3.index)+list(df4.index)+list(df5.index)
print(df1.index)
# Out:
# Index([ 881,  453, 2004, 1353,  281,  941, 1185, 1159, 1138,  599,
#        ...
#         834, 1730,  353, 1345, 1190, 1375,  185,  701, 1671, 1982],
#       dtype='int64', length=415)

# %%
train = pd.concat([df1,df2,df3,df4], axis=0)
train = train.dropna()
train.head()
# Out:
#                0           1          2          3          4          5  \
# 881   -91.556946   78.449265 -14.618045  10.016244  -8.415580 -11.160835
# 453  -458.463530  229.360240  86.695310 -15.900723 -34.656467  -5.903579
# 2004 -284.117160  102.058000  -1.718338  47.854800  -7.803963  -2.370697
# 1353 -518.301150  135.260790 -44.215916  23.724130 -12.291013   5.559977
# 281  -292.163700  146.814620 -46.721610  11.402154  -6.476166  -9.189196
#
#               6         7          8          9  ...       171       172  \
# 881   -8.482311 -2.923860  -8.585278  -2.160674  ...  0.646073  0.673057
# 453   14.054460  3.133542 -16.770098 -17.911320  ...  0.482781  0.508412
# 2004   2.721384 -4.387910 -10.155414   9.340995  ...  0.479485  0.470296
# 1353 -22.077847  6.121159 -11.776861  -3.880132  ...  0.621856  0.610896
# 281  -20.917719 -5.312337 -14.722490  -4.853586  ...  0.605104  0.709732
#
#            173       174       175       176       177       178       179  \
# 881   0.673562  0.649193  0.637028  0.708794  0.664702  0.636884  0.561531
# 453   0.486688  0.482195  0.571344  0.664326  0.616785  0.593982  0.538774
# 2004  0.425867  0.421498  0.468640  0.539623  0.569123  0.516623  0.496454
# 1353  0.541011  0.472360  0.452516  0.453391  0.494902  0.613763  0.671313
# 281   0.534772  0.523089  0.560086  0.527512  0.535581  0.529238  0.530289
#
#       class
# 881    2.88
# 453    2.44
# 2004   3.38
# 1353   3.07
# 281    2.46
#
# [5 rows x 181 columns]

# %%
#run call the transformer model
#df_read = df.copy()
#df_read=(df_read-df_read.mean())/df_read.std()
from sklearn.model_selection import train_test_split

#train, test = train_test_split(df_read, test_size=0.2)

train = pd.concat([df1,df2,df3,df4], axis=0)
test = df5.copy()

Y_train = np.array(train['class'])
X_train= np.array(train.drop(['0','5','9','108', 'class'],axis=1))
X_train=X_train.reshape(X_train.shape[0], 1 , X_train.shape[1])
print(X_train.shape[1])
print(X_train.shape)

Y_val=np.array(test['class'])
X_val = np.array(test.drop(['0','5','9','108', 'class'],axis=1))
X_val=X_val.reshape(X_val.shape[0], 1 , X_val.shape[1])
NUM_LAYERS =  4

D_MODEL = X_train.shape[2]
print('d_model', D_MODEL)
NUM_HEADS =  4
print('num_heads', NUM_HEADS)
UNITS =  2048
DROPOUT = 0.1 #0.1
TIME_STEPS= X_train.shape[1]
print('TIME STEPS', TIME_STEPS)
OUTPUT_SIZE=1
batch_size=64

model = transformer(
  time_steps=TIME_STEPS,
  num_layers=NUM_LAYERS,
  units=UNITS,
  d_model=D_MODEL,
  num_heads=NUM_HEADS,
  dropout=DROPOUT,
  output_size=OUTPUT_SIZE,
  projection='linear')

#run
# model.compile(optimizer=tf.keras.optimizers.Adam(0.00005), loss='mae') #org
model.compile(optimizer=tf.keras.optimizers.Adam(0.000003), loss='mse')
# model.compile(optimizer=tf.keras.optimizers.SGD(0.01), loss='mae')
#
# callback = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience=80, restore_best_weights=True)
# history = model.fit(X_train,Y_train, epochs=1000, validation_data=(X_val, Y_val), callbacks=[callback])
history = model.fit(X_train,Y_train, epochs=1000, validation_data=(X_val, Y_val))
# Out:
# 1
# (1660, 1, 176)
# d_model 176
# num_heads 4
# TIME STEPS 1
# linear
# KerasTensor(type_spec=TensorSpec(shape=(None, 1, 1, None), dtype=tf.float32, name='padding_mask'), name='padding_mask', description="created by layer 'padding_mask'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1, 1, None), dtype=tf.float32, name='padding_mask'), name='padding_mask', description="created by layer 'padding_mask'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1, 1, None), dtype=tf.float32, name='padding_mask'), name='padding_mask', description="created by layer 'padding_mask'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1, 1, None), dtype=tf.float32, name='padding_mask'), name='padding_mask', description="created by layer 'padding_mask'")
# Epoch 1/1000
# 52/52 [==============================] - 13s 44ms/step - loss: 4.8235 - val_loss: 2.8327
# Epoch 2/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 3.0306 - val_loss: 2.8189
# Epoch 3/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 2.6127 - val_loss: 2.7487
# Epoch 4/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 2.4785 - val_loss: 2.6642
# Epoch 5/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 2.3407 - val_loss: 2.5221
# Epoch 6/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 2.3117 - val_loss: 2.4501
# Epoch 7/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 2.2750 - val_loss: 2.3314
# Epoch 8/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 2.1419 - val_loss: 2.2399
# Epoch 9/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 2.1542 - val_loss: 2.2934
# Epoch 10/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 2.1942 - val_loss: 2.1782
# Epoch 11/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 2.1230 - val_loss: 2.1172
# Epoch 12/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 2.0947 - val_loss: 2.1423
# Epoch 13/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 2.0118 - val_loss: 2.0693
# Epoch 14/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.9957 - val_loss: 2.1006
# Epoch 15/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 2.0357 - val_loss: 2.0532
# Epoch 16/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.9779 - val_loss: 2.0916
# Epoch 17/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.9472 - val_loss: 1.9213
# Epoch 18/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.9760 - val_loss: 1.9901
# Epoch 19/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.9219 - val_loss: 1.9695
# Epoch 20/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.9664 - val_loss: 1.9494
# Epoch 21/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.8688 - val_loss: 1.9097
# Epoch 22/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.8842 - val_loss: 1.8550
# Epoch 23/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.8769 - val_loss: 1.9058
# Epoch 24/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.8725 - val_loss: 1.8977
# Epoch 25/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.8635 - val_loss: 1.8453
# Epoch 26/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.8698 - val_loss: 1.8523
# Epoch 27/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.8591 - val_loss: 1.7834
# Epoch 28/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.7408 - val_loss: 1.7839
# Epoch 29/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.7799 - val_loss: 1.8298
# Epoch 30/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.7582 - val_loss: 1.7860
# Epoch 31/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.7896 - val_loss: 1.7642
# Epoch 32/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.6969 - val_loss: 1.8302
# Epoch 33/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.7712 - val_loss: 1.7647
# Epoch 34/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.7876 - val_loss: 1.7599
# Epoch 35/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.7470 - val_loss: 1.7138
# Epoch 36/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.7405 - val_loss: 1.6920
# Epoch 37/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.7405 - val_loss: 1.7146
# Epoch 38/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.7285 - val_loss: 1.7017
# Epoch 39/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.7294 - val_loss: 1.6663
# Epoch 40/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.7502 - val_loss: 1.6541
# Epoch 41/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.6647 - val_loss: 1.6984
# Epoch 42/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.6573 - val_loss: 1.6701
# Epoch 43/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.6869 - val_loss: 1.6992
# Epoch 44/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.6422 - val_loss: 1.7010
# Epoch 45/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.6774 - val_loss: 1.6615
# Epoch 46/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.6005 - val_loss: 1.6678
# Epoch 47/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5677 - val_loss: 1.6278
# Epoch 48/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.6623 - val_loss: 1.6495
# Epoch 49/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.6015 - val_loss: 1.6504
# Epoch 50/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.6035 - val_loss: 1.5917
# Epoch 51/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.6569 - val_loss: 1.6462
# Epoch 52/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.6951 - val_loss: 1.6220
# Epoch 53/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5999 - val_loss: 1.6204
# Epoch 54/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.6420 - val_loss: 1.5985
# Epoch 55/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5483 - val_loss: 1.6141
# Epoch 56/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5984 - val_loss: 1.5280
# Epoch 57/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5729 - val_loss: 1.5572
# Epoch 58/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5271 - val_loss: 1.5894
# Epoch 59/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5547 - val_loss: 1.5233
# Epoch 60/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5511 - val_loss: 1.5522
# Epoch 61/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5944 - val_loss: 1.5701
# Epoch 62/1000
# 52/52 [==============================] - 1s 18ms/step - loss: 1.4996 - val_loss: 1.5116
# Epoch 63/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5585 - val_loss: 1.5465
# Epoch 64/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5631 - val_loss: 1.5140
# Epoch 65/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5893 - val_loss: 1.5246
# Epoch 66/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5502 - val_loss: 1.5216
# Epoch 67/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5100 - val_loss: 1.5165
# Epoch 68/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5032 - val_loss: 1.5084
# Epoch 69/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5098 - val_loss: 1.5130
# Epoch 70/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5439 - val_loss: 1.4601
# Epoch 71/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5657 - val_loss: 1.5113
# Epoch 72/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5723 - val_loss: 1.5108
# Epoch 73/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5023 - val_loss: 1.4570
# Epoch 74/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5110 - val_loss: 1.5119
# Epoch 75/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5233 - val_loss: 1.4542
# Epoch 76/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5085 - val_loss: 1.5147
# Epoch 77/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5115 - val_loss: 1.4393
# Epoch 78/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5326 - val_loss: 1.4697
# Epoch 79/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4918 - val_loss: 1.4698
# Epoch 80/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5138 - val_loss: 1.4695
# Epoch 81/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4950 - val_loss: 1.4594
# Epoch 82/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4625 - val_loss: 1.4270
# Epoch 83/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4784 - val_loss: 1.4292
# Epoch 84/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5627 - val_loss: 1.4812
# Epoch 85/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5003 - val_loss: 1.4386
# Epoch 86/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4399 - val_loss: 1.4319
# Epoch 87/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4978 - val_loss: 1.4267
# Epoch 88/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4392 - val_loss: 1.4426
# Epoch 89/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4763 - val_loss: 1.4184
# Epoch 90/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.5037 - val_loss: 1.4371
# Epoch 91/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4849 - val_loss: 1.4102
# Epoch 92/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4354 - val_loss: 1.4410
# Epoch 93/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4168 - val_loss: 1.4045
# Epoch 94/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4758 - val_loss: 1.4144
# Epoch 95/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4425 - val_loss: 1.3871
# Epoch 96/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4596 - val_loss: 1.3708
# Epoch 97/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4492 - val_loss: 1.4199
# Epoch 98/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4222 - val_loss: 1.4232
# Epoch 99/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3805 - val_loss: 1.3977
# Epoch 100/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4108 - val_loss: 1.4024
# Epoch 101/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4003 - val_loss: 1.3792
# Epoch 102/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4175 - val_loss: 1.3908
# Epoch 103/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4230 - val_loss: 1.3838
# Epoch 104/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4173 - val_loss: 1.3818
# Epoch 105/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4619 - val_loss: 1.4039
# Epoch 106/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3803 - val_loss: 1.3643
# Epoch 107/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3897 - val_loss: 1.3849
# Epoch 108/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3826 - val_loss: 1.3798
# Epoch 109/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3609 - val_loss: 1.3736
# Epoch 110/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3764 - val_loss: 1.3731
# Epoch 111/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4370 - val_loss: 1.3996
# Epoch 112/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4231 - val_loss: 1.3636
# Epoch 113/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4115 - val_loss: 1.3846
# Epoch 114/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4042 - val_loss: 1.3573
# Epoch 115/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3759 - val_loss: 1.3759
# Epoch 116/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4161 - val_loss: 1.3487
# Epoch 117/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3815 - val_loss: 1.3566
# Epoch 118/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4103 - val_loss: 1.3472
# Epoch 119/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3901 - val_loss: 1.3591
# Epoch 120/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3875 - val_loss: 1.3229
# Epoch 121/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3967 - val_loss: 1.3405
# Epoch 122/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3525 - val_loss: 1.3648
# Epoch 123/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3678 - val_loss: 1.3714
# Epoch 124/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4135 - val_loss: 1.3433
# Epoch 125/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3954 - val_loss: 1.3283
# Epoch 126/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3749 - val_loss: 1.3569
# Epoch 127/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3542 - val_loss: 1.3284
# Epoch 128/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3595 - val_loss: 1.3346
# Epoch 129/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3764 - val_loss: 1.3148
# Epoch 130/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.4152 - val_loss: 1.3370
# Epoch 131/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3478 - val_loss: 1.3023
# Epoch 132/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3455 - val_loss: 1.3424
# Epoch 133/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3459 - val_loss: 1.3113
# Epoch 134/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3798 - val_loss: 1.3152
# Epoch 135/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3768 - val_loss: 1.3162
# Epoch 136/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3731 - val_loss: 1.3246
# Epoch 137/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3561 - val_loss: 1.3102
# Epoch 138/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3896 - val_loss: 1.3067
# Epoch 139/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3322 - val_loss: 1.3185
# Epoch 140/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3501 - val_loss: 1.2831
# Epoch 141/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3048 - val_loss: 1.3111
# Epoch 142/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3358 - val_loss: 1.2839
# Epoch 143/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3741 - val_loss: 1.3160
# Epoch 144/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2945 - val_loss: 1.3027
# Epoch 145/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3473 - val_loss: 1.3134
# Epoch 146/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3235 - val_loss: 1.3038
# Epoch 147/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3593 - val_loss: 1.3135
# Epoch 148/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3555 - val_loss: 1.2801
# Epoch 149/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3232 - val_loss: 1.3083
# Epoch 150/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3571 - val_loss: 1.2803
# Epoch 151/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3306 - val_loss: 1.2729
# Epoch 152/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2832 - val_loss: 1.2965
# Epoch 153/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3236 - val_loss: 1.2883
# Epoch 154/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3129 - val_loss: 1.3188
# Epoch 155/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3374 - val_loss: 1.2876
# Epoch 156/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3058 - val_loss: 1.2595
# Epoch 157/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3248 - val_loss: 1.2746
# Epoch 158/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3147 - val_loss: 1.2843
# Epoch 159/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3050 - val_loss: 1.2559
# Epoch 160/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3216 - val_loss: 1.3042
# Epoch 161/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3286 - val_loss: 1.2701
# Epoch 162/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3002 - val_loss: 1.2637
# Epoch 163/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3107 - val_loss: 1.2557
# Epoch 164/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2873 - val_loss: 1.2764
# Epoch 165/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3071 - val_loss: 1.2411
# Epoch 166/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3226 - val_loss: 1.2808
# Epoch 167/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3044 - val_loss: 1.2539
# Epoch 168/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2964 - val_loss: 1.2718
# Epoch 169/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3141 - val_loss: 1.2548
# Epoch 170/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3170 - val_loss: 1.2562
# Epoch 171/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3275 - val_loss: 1.2450
# Epoch 172/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2411 - val_loss: 1.2483
# Epoch 173/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2861 - val_loss: 1.2841
# Epoch 174/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2893 - val_loss: 1.2415
# Epoch 175/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2871 - val_loss: 1.2501
# Epoch 176/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2705 - val_loss: 1.2376
# Epoch 177/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2984 - val_loss: 1.2572
# Epoch 178/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3026 - val_loss: 1.2489
# Epoch 179/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3062 - val_loss: 1.2656
# Epoch 180/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3285 - val_loss: 1.2637
# Epoch 181/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2502 - val_loss: 1.2344
# Epoch 182/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2808 - val_loss: 1.2332
# Epoch 183/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2835 - val_loss: 1.2462
# Epoch 184/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2977 - val_loss: 1.2527
# Epoch 185/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2777 - val_loss: 1.2211
# Epoch 186/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2616 - val_loss: 1.2216
# Epoch 187/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2250 - val_loss: 1.2484
# Epoch 188/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.3039 - val_loss: 1.2203
# Epoch 189/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2622 - val_loss: 1.2487
# Epoch 190/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2412 - val_loss: 1.2412
# Epoch 191/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2430 - val_loss: 1.2243
# Epoch 192/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2945 - val_loss: 1.2302
# Epoch 193/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2931 - val_loss: 1.2252
# Epoch 194/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2421 - val_loss: 1.2215
# Epoch 195/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2476 - val_loss: 1.2166
# Epoch 196/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2196 - val_loss: 1.2245
# Epoch 197/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2296 - val_loss: 1.2563
# Epoch 198/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2984 - val_loss: 1.2296
# Epoch 199/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2799 - val_loss: 1.2504
# Epoch 200/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2550 - val_loss: 1.2194
# Epoch 201/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2143 - val_loss: 1.2274
# Epoch 202/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2458 - val_loss: 1.2208
# Epoch 203/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2704 - val_loss: 1.2027
# Epoch 204/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2164 - val_loss: 1.2433
# Epoch 205/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2587 - val_loss: 1.2069
# Epoch 206/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2389 - val_loss: 1.2087
# Epoch 207/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2260 - val_loss: 1.2097
# Epoch 208/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2346 - val_loss: 1.2050
# Epoch 209/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2149 - val_loss: 1.2090
# Epoch 210/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2521 - val_loss: 1.2155
# Epoch 211/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2028 - val_loss: 1.2065
# Epoch 212/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2284 - val_loss: 1.2262
# Epoch 213/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2596 - val_loss: 1.1983
# Epoch 214/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2829 - val_loss: 1.2067
# Epoch 215/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2011 - val_loss: 1.2122
# Epoch 216/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2071 - val_loss: 1.2142
# Epoch 217/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2356 - val_loss: 1.2002
# Epoch 218/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2345 - val_loss: 1.2169
# Epoch 219/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2172 - val_loss: 1.2140
# Epoch 220/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2341 - val_loss: 1.2123
# Epoch 221/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2510 - val_loss: 1.1948
# Epoch 222/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2411 - val_loss: 1.2108
# Epoch 223/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2339 - val_loss: 1.1929
# Epoch 224/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2609 - val_loss: 1.2064
# Epoch 225/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2144 - val_loss: 1.1950
# Epoch 226/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2450 - val_loss: 1.1951
# Epoch 227/1000
# 52/52 [==============================] - 1s 18ms/step - loss: 1.2397 - val_loss: 1.1883
# Epoch 228/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2339 - val_loss: 1.1883
# Epoch 229/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2057 - val_loss: 1.2183
# Epoch 230/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2151 - val_loss: 1.1952
# Epoch 231/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2346 - val_loss: 1.2034
# Epoch 232/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2145 - val_loss: 1.2156
# Epoch 233/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1919 - val_loss: 1.1966
# Epoch 234/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2230 - val_loss: 1.1771
# Epoch 235/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1990 - val_loss: 1.1904
# Epoch 236/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2050 - val_loss: 1.1714
# Epoch 237/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2084 - val_loss: 1.1707
# Epoch 238/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2244 - val_loss: 1.2091
# Epoch 239/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2317 - val_loss: 1.1841
# Epoch 240/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2142 - val_loss: 1.1819
# Epoch 241/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2798 - val_loss: 1.1598
# Epoch 242/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2294 - val_loss: 1.1787
# Epoch 243/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1898 - val_loss: 1.1724
# Epoch 244/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 1.2064 - val_loss: 1.1665
# Epoch 245/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2415 - val_loss: 1.1715
# Epoch 246/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2303 - val_loss: 1.1713
# Epoch 247/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 1.1820 - val_loss: 1.1770
# Epoch 248/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 1.2220 - val_loss: 1.1708
# Epoch 249/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 1.2126 - val_loss: 1.1966
# Epoch 250/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1939 - val_loss: 1.1668
# Epoch 251/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 1.2079 - val_loss: 1.1816
# Epoch 252/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2126 - val_loss: 1.1507
# Epoch 253/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 1.1760 - val_loss: 1.1727
# Epoch 254/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1941 - val_loss: 1.1733
# Epoch 255/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 1.1964 - val_loss: 1.1578
# Epoch 256/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1929 - val_loss: 1.1667
# Epoch 257/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 1.1842 - val_loss: 1.1622
# Epoch 258/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1740 - val_loss: 1.1652
# Epoch 259/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 1.1897 - val_loss: 1.1626
# Epoch 260/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2312 - val_loss: 1.1474
# Epoch 261/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1757 - val_loss: 1.1667
# Epoch 262/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 1.2237 - val_loss: 1.1595
# Epoch 263/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 1.1928 - val_loss: 1.1496
# Epoch 264/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 1.2057 - val_loss: 1.1621
# Epoch 265/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2109 - val_loss: 1.1656
# Epoch 266/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1831 - val_loss: 1.1408
# Epoch 267/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 1.1348 - val_loss: 1.1680
# Epoch 268/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1697 - val_loss: 1.1563
# Epoch 269/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1905 - val_loss: 1.1764
# Epoch 270/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1677 - val_loss: 1.1549
# Epoch 271/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2000 - val_loss: 1.1534
# Epoch 272/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1908 - val_loss: 1.1529
# Epoch 273/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1660 - val_loss: 1.1408
# Epoch 274/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1869 - val_loss: 1.1460
# Epoch 275/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1877 - val_loss: 1.1503
# Epoch 276/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1876 - val_loss: 1.1345
# Epoch 277/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1524 - val_loss: 1.1494
# Epoch 278/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1703 - val_loss: 1.1403
# Epoch 279/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1854 - val_loss: 1.1304
# Epoch 280/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1612 - val_loss: 1.1495
# Epoch 281/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1634 - val_loss: 1.1596
# Epoch 282/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1785 - val_loss: 1.1446
# Epoch 283/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1931 - val_loss: 1.1403
# Epoch 284/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1871 - val_loss: 1.1514
# Epoch 285/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1557 - val_loss: 1.1394
# Epoch 286/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1647 - val_loss: 1.1472
# Epoch 287/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1794 - val_loss: 1.1464
# Epoch 288/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1595 - val_loss: 1.1378
# Epoch 289/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.2016 - val_loss: 1.1147
# Epoch 290/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1819 - val_loss: 1.1240
# Epoch 291/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1693 - val_loss: 1.1411
# Epoch 292/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1494 - val_loss: 1.1288
# Epoch 293/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1820 - val_loss: 1.1165
# Epoch 294/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1893 - val_loss: 1.1246
# Epoch 295/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1135 - val_loss: 1.1327
# Epoch 296/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1517 - val_loss: 1.1208
# Epoch 297/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1550 - val_loss: 1.1208
# Epoch 298/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1882 - val_loss: 1.1352
# Epoch 299/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1759 - val_loss: 1.1273
# Epoch 300/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1636 - val_loss: 1.1351
# Epoch 301/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1549 - val_loss: 1.1192
# Epoch 302/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1425 - val_loss: 1.1206
# Epoch 303/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1842 - val_loss: 1.1102
# Epoch 304/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1522 - val_loss: 1.1350
# Epoch 305/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1529 - val_loss: 1.1145
# Epoch 306/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1645 - val_loss: 1.1362
# Epoch 307/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1497 - val_loss: 1.1264
# Epoch 308/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1785 - val_loss: 1.1254
# Epoch 309/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1616 - val_loss: 1.1220
# Epoch 310/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1747 - val_loss: 1.1166
# Epoch 311/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1393 - val_loss: 1.1232
# Epoch 312/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1743 - val_loss: 1.1038
# Epoch 313/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1693 - val_loss: 1.1304
# Epoch 314/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1411 - val_loss: 1.1138
# Epoch 315/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1350 - val_loss: 1.1033
# Epoch 316/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1552 - val_loss: 1.1288
# Epoch 317/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1484 - val_loss: 1.0989
# Epoch 318/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1318 - val_loss: 1.1252
# Epoch 319/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1482 - val_loss: 1.1067
# Epoch 320/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1535 - val_loss: 1.1229
# Epoch 321/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1358 - val_loss: 1.1112
# Epoch 322/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1284 - val_loss: 1.1190
# Epoch 323/1000
# 52/52 [==============================] - 1s 18ms/step - loss: 1.1414 - val_loss: 1.1008
# Epoch 324/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1262 - val_loss: 1.1036
# Epoch 325/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1200 - val_loss: 1.0892
# Epoch 326/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1337 - val_loss: 1.1139
# Epoch 327/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1657 - val_loss: 1.0917
# Epoch 328/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1332 - val_loss: 1.1135
# Epoch 329/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1236 - val_loss: 1.1230
# Epoch 330/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0938 - val_loss: 1.1102
# Epoch 331/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1473 - val_loss: 1.1061
# Epoch 332/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1496 - val_loss: 1.1017
# Epoch 333/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1330 - val_loss: 1.1180
# Epoch 334/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1322 - val_loss: 1.0862
# Epoch 335/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1120 - val_loss: 1.1062
# Epoch 336/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1344 - val_loss: 1.1071
# Epoch 337/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1128 - val_loss: 1.1119
# Epoch 338/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1477 - val_loss: 1.0925
# Epoch 339/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1777 - val_loss: 1.0949
# Epoch 340/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1473 - val_loss: 1.1017
# Epoch 341/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1257 - val_loss: 1.1004
# Epoch 342/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1200 - val_loss: 1.0986
# Epoch 343/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1290 - val_loss: 1.1043
# Epoch 344/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1179 - val_loss: 1.0871
# Epoch 345/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1622 - val_loss: 1.0894
# Epoch 346/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0962 - val_loss: 1.1015
# Epoch 347/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1207 - val_loss: 1.1030
# Epoch 348/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1290 - val_loss: 1.1032
# Epoch 349/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1291 - val_loss: 1.0789
# Epoch 350/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1088 - val_loss: 1.0950
# Epoch 351/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1257 - val_loss: 1.0875
# Epoch 352/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1178 - val_loss: 1.1052
# Epoch 353/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1412 - val_loss: 1.0796
# Epoch 354/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0916 - val_loss: 1.0938
# Epoch 355/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1066 - val_loss: 1.0990
# Epoch 356/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1327 - val_loss: 1.1016
# Epoch 357/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1350 - val_loss: 1.0946
# Epoch 358/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1066 - val_loss: 1.0850
# Epoch 359/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1016 - val_loss: 1.1086
# Epoch 360/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1090 - val_loss: 1.1018
# Epoch 361/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0988 - val_loss: 1.0884
# Epoch 362/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1109 - val_loss: 1.0829
# Epoch 363/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1088 - val_loss: 1.0946
# Epoch 364/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1175 - val_loss: 1.0786
# Epoch 365/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1391 - val_loss: 1.0716
# Epoch 366/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1204 - val_loss: 1.0866
# Epoch 367/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1000 - val_loss: 1.0815
# Epoch 368/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1004 - val_loss: 1.0824
# Epoch 369/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0982 - val_loss: 1.0874
# Epoch 370/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0983 - val_loss: 1.0821
# Epoch 371/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0957 - val_loss: 1.0821
# Epoch 372/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1096 - val_loss: 1.0943
# Epoch 373/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1150 - val_loss: 1.0820
# Epoch 374/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0712 - val_loss: 1.0819
# Epoch 375/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1205 - val_loss: 1.0671
# Epoch 376/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1537 - val_loss: 1.0640
# Epoch 377/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1016 - val_loss: 1.0932
# Epoch 378/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0942 - val_loss: 1.0792
# Epoch 379/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1114 - val_loss: 1.0695
# Epoch 380/1000
# 52/52 [==============================] - 1s 18ms/step - loss: 1.1047 - val_loss: 1.0715
# Epoch 381/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1255 - val_loss: 1.0919
# Epoch 382/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1270 - val_loss: 1.0602
# Epoch 383/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1001 - val_loss: 1.0571
# Epoch 384/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1072 - val_loss: 1.0715
# Epoch 385/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0938 - val_loss: 1.0624
# Epoch 386/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0789 - val_loss: 1.0892
# Epoch 387/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1157 - val_loss: 1.0684
# Epoch 388/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0771 - val_loss: 1.0701
# Epoch 389/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0910 - val_loss: 1.0799
# Epoch 390/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1316 - val_loss: 1.0793
# Epoch 391/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0588 - val_loss: 1.0740
# Epoch 392/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1003 - val_loss: 1.0822
# Epoch 393/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0724 - val_loss: 1.0777
# Epoch 394/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0672 - val_loss: 1.0624
# Epoch 395/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1144 - val_loss: 1.0713
# Epoch 396/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0856 - val_loss: 1.0759
# Epoch 397/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1062 - val_loss: 1.0879
# Epoch 398/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0607 - val_loss: 1.0596
# Epoch 399/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0650 - val_loss: 1.0499
# Epoch 400/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0986 - val_loss: 1.0863
# Epoch 401/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0886 - val_loss: 1.0692
# Epoch 402/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0779 - val_loss: 1.0674
# Epoch 403/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1055 - val_loss: 1.0623
# Epoch 404/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0965 - val_loss: 1.0675
# Epoch 405/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0568 - val_loss: 1.0691
# Epoch 406/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0884 - val_loss: 1.0613
# Epoch 407/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0938 - val_loss: 1.0501
# Epoch 408/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0805 - val_loss: 1.0611
# Epoch 409/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0806 - val_loss: 1.0551
# Epoch 410/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0509 - val_loss: 1.0533
# Epoch 411/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0705 - val_loss: 1.0538
# Epoch 412/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0906 - val_loss: 1.0675
# Epoch 413/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0799 - val_loss: 1.0535
# Epoch 414/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0645 - val_loss: 1.0633
# Epoch 415/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0585 - val_loss: 1.0519
# Epoch 416/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0733 - val_loss: 1.0585
# Epoch 417/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 1.0819 - val_loss: 1.0448
# Epoch 418/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0856 - val_loss: 1.0504
# Epoch 419/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0620 - val_loss: 1.0423
# Epoch 420/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0904 - val_loss: 1.0435
# Epoch 421/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0880 - val_loss: 1.0437
# Epoch 422/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1067 - val_loss: 1.0561
# Epoch 423/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0697 - val_loss: 1.0503
# Epoch 424/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1245 - val_loss: 1.0502
# Epoch 425/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0492 - val_loss: 1.0373
# Epoch 426/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0818 - val_loss: 1.0486
# Epoch 427/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0580 - val_loss: 1.0501
# Epoch 428/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0853 - val_loss: 1.0466
# Epoch 429/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0544 - val_loss: 1.0291
# Epoch 430/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0746 - val_loss: 1.0400
# Epoch 431/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0860 - val_loss: 1.0408
# Epoch 432/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0733 - val_loss: 1.0488
# Epoch 433/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0675 - val_loss: 1.0347
# Epoch 434/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0663 - val_loss: 1.0388
# Epoch 435/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0778 - val_loss: 1.0433
# Epoch 436/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0841 - val_loss: 1.0382
# Epoch 437/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0589 - val_loss: 1.0277
# Epoch 438/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.1048 - val_loss: 1.0490
# Epoch 439/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0573 - val_loss: 1.0407
# Epoch 440/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0246 - val_loss: 1.0408
# Epoch 441/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0827 - val_loss: 1.0381
# Epoch 442/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0899 - val_loss: 1.0477
# Epoch 443/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0475 - val_loss: 1.0433
# Epoch 444/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0665 - val_loss: 1.0289
# Epoch 445/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 1.0472 - val_loss: 1.0583
# Epoch 446/1000
# 52/52 [==============================] - 1s 19ms/step - loss: 1.0502 - val_loss: 1.0288
# Epoch 447/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 1.0791 - val_loss: 1.0299
# Epoch 448/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 1.0958 - val_loss: 1.0381
# Epoch 449/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 1.0465 - val_loss: 1.0398
# Epoch 450/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 1.1040 - val_loss: 1.0314
# Epoch 451/1000
# 52/52 [==============================] - 1s 21ms/step - loss: 1.0411 - val_loss: 1.0397
# Epoch 452/1000
# 52/52 [==============================] - 1s 21ms/step - loss: 1.0382 - val_loss: 1.0455
# Epoch 453/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 1.0415 - val_loss: 1.0300
# Epoch 454/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 1.0569 - val_loss: 1.0259
# Epoch 455/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 1.0563 - val_loss: 1.0263
# Epoch 456/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 1.0528 - val_loss: 1.0349
# Epoch 457/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 1.0754 - val_loss: 1.0179
# Epoch 458/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 1.0192 - val_loss: 1.0415
# Epoch 459/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 1.0714 - val_loss: 1.0398
# Epoch 460/1000
# ...
# Epoch 846/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8684 - val_loss: 0.8953
# Epoch 847/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.9041 - val_loss: 0.9045
# Epoch 848/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.9063 - val_loss: 0.8972
# Epoch 849/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.9137 - val_loss: 0.8951
# Epoch 850/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8784 - val_loss: 0.8910
# Epoch 851/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.9076 - val_loss: 0.8906
# Epoch 852/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8891 - val_loss: 0.8961
# Epoch 853/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8964 - val_loss: 0.8896
# Epoch 854/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8830 - val_loss: 0.9022
# Epoch 855/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8609 - val_loss: 0.8986
# Epoch 856/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8976 - val_loss: 0.8867
# Epoch 857/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.9017 - val_loss: 0.8980
# Epoch 858/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.9070 - val_loss: 0.9006
# Epoch 859/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8981 - val_loss: 0.8994
# Epoch 860/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8663 - val_loss: 0.8984
# Epoch 861/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8998 - val_loss: 0.8943
# Epoch 862/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.9103 - val_loss: 0.8947
# Epoch 863/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.9126 - val_loss: 0.8920
# Epoch 864/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8866 - val_loss: 0.8960
# Epoch 865/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.9180 - val_loss: 0.8873
# Epoch 866/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8743 - val_loss: 0.8968
# Epoch 867/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8834 - val_loss: 0.8958
# Epoch 868/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8726 - val_loss: 0.8934
# Epoch 869/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8865 - val_loss: 0.8889
# Epoch 870/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8792 - val_loss: 0.9042
# Epoch 871/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8881 - val_loss: 0.8913
# Epoch 872/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8692 - val_loss: 0.9042
# Epoch 873/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8902 - val_loss: 0.8923
# Epoch 874/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8727 - val_loss: 0.8962
# Epoch 875/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8941 - val_loss: 0.9010
# Epoch 876/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8925 - val_loss: 0.9050
# Epoch 877/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8820 - val_loss: 0.8910
# Epoch 878/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8775 - val_loss: 0.8977
# Epoch 879/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8805 - val_loss: 0.8850
# Epoch 880/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8930 - val_loss: 0.8905
# Epoch 881/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8840 - val_loss: 0.8834
# Epoch 882/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8802 - val_loss: 0.8997
# Epoch 883/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8808 - val_loss: 0.8817
# Epoch 884/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8656 - val_loss: 0.8949
# Epoch 885/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8604 - val_loss: 0.8894
# Epoch 886/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8913 - val_loss: 0.8852
# Epoch 887/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8936 - val_loss: 0.8880
# Epoch 888/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8782 - val_loss: 0.8844
# Epoch 889/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8925 - val_loss: 0.8875
# Epoch 890/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8902 - val_loss: 0.9024
# Epoch 891/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8965 - val_loss: 0.8926
# Epoch 892/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8890 - val_loss: 0.8884
# Epoch 893/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8945 - val_loss: 0.8818
# Epoch 894/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8967 - val_loss: 0.8915
# Epoch 895/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8930 - val_loss: 0.8908
# Epoch 896/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.9041 - val_loss: 0.8898
# Epoch 897/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.9145 - val_loss: 0.8893
# Epoch 898/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8549 - val_loss: 0.8911
# Epoch 899/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8618 - val_loss: 0.8905
# Epoch 900/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.9015 - val_loss: 0.8845
# Epoch 901/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8852 - val_loss: 0.8900
# Epoch 902/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8628 - val_loss: 0.8901
# Epoch 903/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8917 - val_loss: 0.8909
# Epoch 904/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.9202 - val_loss: 0.8964
# Epoch 905/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8948 - val_loss: 0.8910
# Epoch 906/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8773 - val_loss: 0.9012
# Epoch 907/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8670 - val_loss: 0.8987
# Epoch 908/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8706 - val_loss: 0.8893
# Epoch 909/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8632 - val_loss: 0.8935
# Epoch 910/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.9070 - val_loss: 0.8996
# Epoch 911/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8701 - val_loss: 0.9043
# Epoch 912/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8604 - val_loss: 0.8880
# Epoch 913/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8772 - val_loss: 0.8831
# Epoch 914/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8815 - val_loss: 0.8798
# Epoch 915/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.9041 - val_loss: 0.8957
# Epoch 916/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8869 - val_loss: 0.8892
# Epoch 917/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8987 - val_loss: 0.8840
# Epoch 918/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8787 - val_loss: 0.8861
# Epoch 919/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8915 - val_loss: 0.8939
# Epoch 920/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8690 - val_loss: 0.8940
# Epoch 921/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8601 - val_loss: 0.8891
# Epoch 922/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8642 - val_loss: 0.8884
# Epoch 923/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8852 - val_loss: 0.8896
# Epoch 924/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8847 - val_loss: 0.8873
# Epoch 925/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8960 - val_loss: 0.8835
# Epoch 926/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.9066 - val_loss: 0.8811
# Epoch 927/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8865 - val_loss: 0.8833
# Epoch 928/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8740 - val_loss: 0.8872
# Epoch 929/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8761 - val_loss: 0.8936
# Epoch 930/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8819 - val_loss: 0.8954
# Epoch 931/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8736 - val_loss: 0.8852
# Epoch 932/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8539 - val_loss: 0.8978
# Epoch 933/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8583 - val_loss: 0.8964
# Epoch 934/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8912 - val_loss: 0.8727
# Epoch 935/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8797 - val_loss: 0.8942
# Epoch 936/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8569 - val_loss: 0.8783
# Epoch 937/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8660 - val_loss: 0.8880
# Epoch 938/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8629 - val_loss: 0.8918
# Epoch 939/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8737 - val_loss: 0.8934
# Epoch 940/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8561 - val_loss: 0.8830
# Epoch 941/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8571 - val_loss: 0.8931
# Epoch 942/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8473 - val_loss: 0.8826
# Epoch 943/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8764 - val_loss: 0.8832
# Epoch 944/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8840 - val_loss: 0.8837
# Epoch 945/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8786 - val_loss: 0.8880
# Epoch 946/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8637 - val_loss: 0.8829
# Epoch 947/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8862 - val_loss: 0.8799
# Epoch 948/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8685 - val_loss: 0.8904
# Epoch 949/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8650 - val_loss: 0.8856
# Epoch 950/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8810 - val_loss: 0.8851
# Epoch 951/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8707 - val_loss: 0.8892
# Epoch 952/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8820 - val_loss: 0.8780
# Epoch 953/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8622 - val_loss: 0.8836
# Epoch 954/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8445 - val_loss: 0.8860
# Epoch 955/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8393 - val_loss: 0.8805
# Epoch 956/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8787 - val_loss: 0.8851
# Epoch 957/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8750 - val_loss: 0.8820
# Epoch 958/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8711 - val_loss: 0.8870
# Epoch 959/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8662 - val_loss: 0.8885
# Epoch 960/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8530 - val_loss: 0.8878
# Epoch 961/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8663 - val_loss: 0.8840
# Epoch 962/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8661 - val_loss: 0.8908
# Epoch 963/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8647 - val_loss: 0.8867
# Epoch 964/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8587 - val_loss: 0.8818
# Epoch 965/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8869 - val_loss: 0.8962
# Epoch 966/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8822 - val_loss: 0.8767
# Epoch 967/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8433 - val_loss: 0.8885
# Epoch 968/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8607 - val_loss: 0.8875
# Epoch 969/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8663 - val_loss: 0.8801
# Epoch 970/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8373 - val_loss: 0.8836
# Epoch 971/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8687 - val_loss: 0.8850
# Epoch 972/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8556 - val_loss: 0.8821
# Epoch 973/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8470 - val_loss: 0.8923
# Epoch 974/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8412 - val_loss: 0.8802
# Epoch 975/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8850 - val_loss: 0.8948
# Epoch 976/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8745 - val_loss: 0.8780
# Epoch 977/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8822 - val_loss: 0.8859
# Epoch 978/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8546 - val_loss: 0.8746
# Epoch 979/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8580 - val_loss: 0.8891
# Epoch 980/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8319 - val_loss: 0.8808
# Epoch 981/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8708 - val_loss: 0.8801
# Epoch 982/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8579 - val_loss: 0.8903
# Epoch 983/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8815 - val_loss: 0.8859
# Epoch 984/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8466 - val_loss: 0.8844
# Epoch 985/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8507 - val_loss: 0.8900
# Epoch 986/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8776 - val_loss: 0.8862
# Epoch 987/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8399 - val_loss: 0.8695
# Epoch 988/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8609 - val_loss: 0.8758
# Epoch 989/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8436 - val_loss: 0.8768
# Epoch 990/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8576 - val_loss: 0.8765
# Epoch 991/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8729 - val_loss: 0.8825
# Epoch 992/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8568 - val_loss: 0.8800
# Epoch 993/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8549 - val_loss: 0.8870
# Epoch 994/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8352 - val_loss: 0.8839
# Epoch 995/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8526 - val_loss: 0.8813
# Epoch 996/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8509 - val_loss: 0.8885
# Epoch 997/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8321 - val_loss: 0.8810
# Epoch 998/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8617 - val_loss: 0.8729
# Epoch 999/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8476 - val_loss: 0.8780
# Epoch 1000/1000
# 52/52 [==============================] - 1s 20ms/step - loss: 0.8462 - val_loss: 0.8745

# %%
#run
import time
st = time.time()
p1 = np.array(model(X_val)).flatten()
end = time.time()
# print(end, st, len(p1))
print((end-st)/len(p1))
p2 = np.array(model(X_train)).flatten()
print(X_train.shape)
print(X_val.shape)
# Out:
# 0.00037309520215873256
# (1660, 1, 176)
# (415, 1, 176)

# %%
from scipy import stats
from scipy.stats import kendalltau
print("training")
print(np.corrcoef(p2, Y_train), stats.spearmanr(p2, Y_train), kendalltau(p2,Y_train).correlation)
print("Validation")
print(np.corrcoef(p1, Y_val)[1][0], stats.spearmanr(p1, Y_val).correlation, kendalltau(p1,Y_val).correlation)
# Out:
# training
# [[1.         0.74849451]
#  [0.74849451 1.        ]] SignificanceResult(statistic=0.7493208976225663, pvalue=4.2164156017597297e-299) 0.5537683816473855
# Validation
# 0.6980424636924172 0.6845096819894705 0.5022355721849291

# %%
X_train.shape
# Out:
# (1660, 1, 176)

# %%
#run
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.savefig("audio_dm_3_featu_.jpg")

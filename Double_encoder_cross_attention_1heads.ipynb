# %%
#run
# !pip install spafe pandas tensorflow seaborn opencv-python tqdm librosa
# Out:
# Requirement already satisfied: spafe in /home/ashutosh/anaconda3/lib/python3.11/site-packages (0.3.2)
# Requirement already satisfied: pandas in /home/ashutosh/anaconda3/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: tensorflow in /home/ashutosh/anaconda3/lib/python3.11/site-packages (2.14.0)
# Requirement already satisfied: seaborn in /home/ashutosh/anaconda3/lib/python3.11/site-packages (0.12.2)
# Requirement already satisfied: opencv-python in /home/ashutosh/anaconda3/lib/python3.11/site-packages (4.8.1.78)
# Requirement already satisfied: tqdm in /home/ashutosh/anaconda3/lib/python3.11/site-packages (4.65.0)
# Requirement already satisfied: librosa in /home/ashutosh/anaconda3/lib/python3.11/site-packages (0.10.1)
# Requirement already satisfied: numpy>=1.21 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from spafe) (1.24.3)
# Requirement already satisfied: scipy>=1.7.3 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from spafe) (1.11.1)
# Requirement already satisfied: typing-extensions in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from spafe) (4.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: absl-py>=1.0.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (4.24.4)
# Requirement already satisfied: setuptools in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.59.0)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: audioread>=2.1.9 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from librosa) (1.3.0)
# Requirement already satisfied: joblib>=0.14 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from librosa) (1.2.0)
# Requirement already satisfied: decorator>=4.3.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from librosa) (0.57.1)
# Requirement already satisfied: soundfile>=0.12.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from librosa) (1.7.0)
# Requirement already satisfied: soxr>=0.3.2 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from librosa) (0.3.7)
# Requirement already satisfied: lazy-loader>=0.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from librosa) (0.2)
# Requirement already satisfied: msgpack>=1.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from librosa) (1.0.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.38.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from numba>=0.51.0->librosa) (0.40.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from pooch>=1.0->librosa) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from pooch>=1.0->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.23.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.2.3)
# Requirement already satisfied: pycparser in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/ashutosh/anaconda3/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (3.2.2)

# %%
#run
import pandas as pd
import os
import librosa
import librosa.display
import numpy as np
import IPython.display as ipd
import matplotlib.pyplot as plt
# %matplotlib inline

from collections import defaultdict
from spafe.utils import vis
from spafe.features.lfcc import lfcc

# %%
#run
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from sklearn import metrics
from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
# Out:
# 2023-10-15 16:28:24.456552: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-10-15 16:28:24.460249: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-10-15 16:28:24.502879: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-15 16:28:24.503003: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-15 16:28:24.503052: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-15 16:28:24.511868: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-10-15 16:28:24.512728: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-15 16:28:25.638855: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#run
import pandas as pd
import numpy as np
import os.path
import matplotlib.pyplot as plt
import seaborn as sns
import gc

from PIL import Image

# %matplotlib inline
from tensorflow import keras
from tensorflow.keras.applications import ResNet50,ResNet101
import cv2
from tqdm import tqdm
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import backend as K
from tensorflow.keras import applications
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing import image
from sklearn.model_selection import StratifiedKFold , KFold ,RepeatedKFold
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

# %%
#run
def scaled_dot_product_attention(query, key, value, mask):
  matmul_qk = tf.matmul(query, key, transpose_b=True)

  depth = tf.cast(tf.shape(key)[-1], tf.float32)
  logits = matmul_qk / tf.math.sqrt(depth)

  # add the mask zero out padding tokens.
  if mask is not None:
    logits += (mask * -1e9)

  attention_weights = tf.nn.softmax(logits, axis=-1)

  return tf.matmul(attention_weights, value)

# %%
#run
# This allows to the transformer to know where there is real data and where it is padded
def create_padding_mask(seq):
  seq = tf.cast(tf.math.equal(seq, 0), tf.float32)

  # add extra dimensions to add the padding
  # to the attention logits.
  return seq[:, tf.newaxis, tf.newaxis, :]  # (batch_size, 1, 1, seq_len)

# %%
#run
class MultiHeadAttention(tf.keras.layers.Layer):

  def __init__(self, d_model, num_heads, name="multi_head_attention"):
    super(MultiHeadAttention, self).__init__(name=name)
    self.num_heads = num_heads
    self.d_model = d_model

    assert d_model % self.num_heads == 0

    self.depth = d_model // self.num_heads

    self.query_dense = tf.keras.layers.Dense(units=d_model)
    self.key_dense = tf.keras.layers.Dense(units=d_model)
    self.value_dense = tf.keras.layers.Dense(units=d_model)

    self.dense = tf.keras.layers.Dense(units=d_model)

  def split_heads(self, inputs, batch_size):
    inputs = tf.reshape(
        inputs, shape=(batch_size, -1, self.num_heads, self.depth))
    return tf.transpose(inputs, perm=[0, 2, 1, 3])

  def call(self, inputs):
    query, key, value, mask = inputs['query'], inputs['key'], inputs[
        'value'], inputs['mask']
    batch_size = tf.shape(query)[0]

    # linear layers
    query = self.query_dense(query)
    key = self.key_dense(key)
    value = self.value_dense(value)

    # split heads
    query = self.split_heads(query, batch_size)
    key = self.split_heads(key, batch_size)
    value = self.split_heads(value, batch_size)

    scaled_attention = scaled_dot_product_attention(query, key, value, mask)

    scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])

    concat_attention = tf.reshape(scaled_attention,
                                  (batch_size, -1, self.d_model))

    outputs = self.dense(concat_attention)

    return outputs

# %%
#run
class PositionalEncoding(tf.keras.layers.Layer):

  def __init__(self, position, d_model):
    super(PositionalEncoding, self).__init__()
    self.pos_encoding = self.positional_encoding(position, d_model)

  def get_angles(self, position, i, d_model):
    angles = 1 / tf.pow(10000, (2 * (i // 2)) / tf.cast(d_model, tf.float32))
    return position * angles

  def positional_encoding(self, position, d_model):
    angle_rads = self.get_angles(
        position=tf.range(position, dtype=tf.float32)[:, tf.newaxis],
        i=tf.range(d_model, dtype=tf.float32)[tf.newaxis, :],
        d_model=d_model)
    # apply sin to even index in the array
    sines = tf.math.sin(angle_rads[:, 0::2])
    # apply cos to odd index in the array
    cosines = tf.math.cos(angle_rads[:, 1::2])

    pos_encoding = tf.concat([sines, cosines], axis=-1)
    pos_encoding = pos_encoding[tf.newaxis, ...]
    return tf.cast(pos_encoding, tf.float32)

  def call(self, inputs):
    return inputs + self.pos_encoding[:, :tf.shape(inputs)[1], :]

# %%
#run
def encoder_layer(units, d_model, num_heads, dropout,name="encoder_layer"):
  inputs = tf.keras.Input(shape=(None,d_model ), name="inputs")
  padding_mask = tf.keras.Input(shape=(1, 1, None), name="padding_mask")
  print(padding_mask)

  attention1 = MultiHeadAttention(
      d_model, num_heads, name="attention1")({
          'query': inputs,
          'key': inputs,
          'value': inputs,
          'mask': padding_mask
      })
  attention1 = tf.keras.layers.Dropout(rate=dropout)(attention1)
  attention1 = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(inputs + attention1)
    
  attention2 = MultiHeadAttention(
      d_model, num_heads, name="attention2")({
          'query': inputs,
          'key': inputs,
          'value': inputs,
          'mask': padding_mask
      })
  attention2 = tf.keras.layers.Dropout(rate=dropout)(attention2)
  attention2 = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(inputs + attention2)

  attention3 = MultiHeadAttention(
      d_model, 1, name="attention3")({
          'query': attention1,
          'key': attention2,
          'value': attention1,
          'mask': padding_mask
      })
  attention3 = tf.keras.layers.Dropout(rate=dropout)(attention3)
  attention3 = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(inputs + attention3)
  outputs = tf.keras.layers.Dense(units=units, activation='relu')(attention3)
  outputs = tf.keras.layers.Dense(units=d_model)(outputs)
  outputs = tf.keras.layers.Dropout(rate=dropout)(outputs)
  outputs = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(attention3 + outputs)

  return tf.keras.Model(
      inputs=[inputs, padding_mask], outputs=outputs, name=name)

# %%
#run
def encoder(time_steps,
            num_layers,
            units,
            d_model,
            num_heads,
            dropout,
            projection,
            name="encoder"):
  inputs = tf.keras.Input(shape=(None,d_model), name="inputs")
  padding_mask = tf.keras.Input(shape=(1, 1, None), name="padding_mask")

  if projection=='linear':
    ## We implement a linear projection based on Very Deep Self-Attention Networks for End-to-End Speech Recognition. Retrieved from https://arxiv.org/abs/1904.13377
    projection=tf.keras.layers.Dense( d_model,use_bias=True, activation='linear')(inputs)
    print('linear')

  else:
    projection=tf.identity(inputs)
    print('none')

  projection *= tf.math.sqrt(tf.cast(d_model, tf.float32))
  projection = PositionalEncoding(time_steps, d_model)(projection)

  outputs = tf.keras.layers.Dropout(rate=dropout)(projection)

  for i in range(num_layers):
    outputs = encoder_layer(
        units=units,
        d_model=d_model,
        num_heads=num_heads,
        dropout=dropout,
        name="encoder_layer_{}".format(i),
    )([outputs, padding_mask])

  return tf.keras.Model(
      inputs=[inputs, padding_mask], outputs=outputs, name=name)

# %%
#run
def transformer(time_steps,
                num_layers,
                units,
                d_model,
                num_heads,
                dropout,
                output_size,
                projection,
                name="transformer"):
  inputs = tf.keras.Input(shape=(None,d_model), name="inputs")

  enc_padding_mask = tf.keras.layers.Lambda(
      create_padding_mask, output_shape=(1, 1, None),
      name='enc_padding_mask')(tf.dtypes.cast(

      #Like our input has a dimension of length X d_model but the masking is applied to a vector
      # We get the sum for each row and result is a vector. So, if result is 0 it is because in that position was masked
      tf.math.reduce_sum(
      inputs,
      axis=2,
      keepdims=False,
      name=None
  ), tf.int32))

  enc_outputs = encoder(
      time_steps=time_steps,
      num_layers=num_layers,
      units=units,
      d_model=d_model,
      num_heads=num_heads,
      dropout=dropout,
      projection=projection,
      name='encoder'
  )(inputs=[inputs, enc_padding_mask])

  #We reshape for feeding our FC in the next step
  outputs=tf.reshape(enc_outputs,(-1,time_steps*d_model))

  #We predict our class
  outputs = tf.keras.layers.Dense(units=output_size,use_bias=True, name="outputs")(outputs)

  return tf.keras.Model(inputs=[inputs], outputs=outputs, name='audio_class')

# %%
#run
# num_batch_size = 32
# num_epochs = 500
# N_SPLIT = 10
# num_labels=5
# num_classes=6

# %%
#ajit
# df = pd.read_csv('/content/drive/MyDrive/DatabaseDistorted/final_tii_all_finaldata/features/2075_concatenate5_spectral2.csv')
# dm
# df = pd.read_csv('./DatabaseDistorted/final_tii_all_finaldata/features/2075_concatenate_dm.csv')
df = pd.read_csv('./ablation/latest.csv')


# df = pd.read_csv('/content/drive/MyDrive/DatabaseDistorted/final_tii_all_finaldata/features/melspectogram_mean_newdm_2075.csv')
# df = pd.read_csv('/content/drive/MyDrive/DatabaseDistorted/final_tii_all_finaldata/features/chroma_cqt_simple_mean_newdm_2075.csv')
# df = pd.read_csv('/content/drive/MyDrive/DatabaseDistorted/final_tii_all_finaldata/features/mfcc_simple_mean_newdm_2075.csv')
# df = pd.read_csv('/content/drive/MyDrive/DatabaseDistorted/final_tii_all_finaldata/features/spectral_centroid_meandm_2075_200.csv')

df = df.drop(['Unnamed: 0'], axis = 1)
df = df.dropna()
df.shape
# Out:
# (2075, 181)

# %%
np.random.seed(42)
siz=415
df_read = df.copy()
df1 = df_read.sample(siz)
df_read = df_read.drop(df1.index)
df2 = df_read.sample(siz)
df_read = df_read.drop(df2.index)
df3 = df_read.sample(siz)
df_read = df_read.drop(df3.index)
df4 = df_read.sample(siz)
df_read = df_read.drop(df4.index)
df5 = df_read.copy()

print(df1.shape)
print(df2.shape)
print(df3.shape)
print(df4.shape)
print(df5.shape)
# Out:
# (415, 181)
# (415, 181)
# (415, 181)
# (415, 181)
# (415, 181)

# %%
q = list(df1.index)+list(df2.index)+list(df3.index)+list(df4.index)+list(df5.index)
print(df1.index)
# Out:
# Index([ 881,  453, 2004, 1353,  281,  941, 1185, 1159, 1138,  599,
#        ...
#         834, 1730,  353, 1345, 1190, 1375,  185,  701, 1671, 1982],
#       dtype='int64', length=415)

# %%
train = pd.concat([df1,df2,df3,df4], axis=0)
train = train.dropna()
train.head()
# Out:
#                0           1          2          3          4          5  \
# 881   -91.556946   78.449265 -14.618045  10.016244  -8.415580 -11.160835
# 453  -458.463530  229.360240  86.695310 -15.900723 -34.656467  -5.903579
# 2004 -284.117160  102.058000  -1.718338  47.854800  -7.803963  -2.370697
# 1353 -518.301150  135.260790 -44.215916  23.724130 -12.291013   5.559977
# 281  -292.163700  146.814620 -46.721610  11.402154  -6.476166  -9.189196
#
#               6         7          8          9  ...       171       172  \
# 881   -8.482311 -2.923860  -8.585278  -2.160674  ...  0.646073  0.673057
# 453   14.054460  3.133542 -16.770098 -17.911320  ...  0.482781  0.508412
# 2004   2.721384 -4.387910 -10.155414   9.340995  ...  0.479485  0.470296
# 1353 -22.077847  6.121159 -11.776861  -3.880132  ...  0.621856  0.610896
# 281  -20.917719 -5.312337 -14.722490  -4.853586  ...  0.605104  0.709732
#
#            173       174       175       176       177       178       179  \
# 881   0.673562  0.649193  0.637028  0.708794  0.664702  0.636884  0.561531
# 453   0.486688  0.482195  0.571344  0.664326  0.616785  0.593982  0.538774
# 2004  0.425867  0.421498  0.468640  0.539623  0.569123  0.516623  0.496454
# 1353  0.541011  0.472360  0.452516  0.453391  0.494902  0.613763  0.671313
# 281   0.534772  0.523089  0.560086  0.527512  0.535581  0.529238  0.530289
#
#       class
# 881    2.88
# 453    2.44
# 2004   3.38
# 1353   3.07
# 281    2.46
#
# [5 rows x 181 columns]

# %%
#run call the transformer model
#df_read = df.copy()
#df_read=(df_read-df_read.mean())/df_read.std()
from sklearn.model_selection import train_test_split

#train, test = train_test_split(df_read, test_size=0.2)

train = pd.concat([df1,df2,df3,df4], axis=0)
test = df5.copy()

Y_train = np.array(train['class'])
X_train= np.array(train.drop(['0','5','9','108', 'class'],axis=1))
X_train=X_train.reshape(X_train.shape[0], 1 , X_train.shape[1])
print(X_train.shape[1])
print(X_train.shape)

Y_val=np.array(test['class'])
X_val = np.array(test.drop(['0','5','9','108', 'class'],axis=1))
X_val=X_val.reshape(X_val.shape[0], 1 , X_val.shape[1])
NUM_LAYERS =  4

D_MODEL = X_train.shape[2]
print('d_model', D_MODEL)
NUM_HEADS =  4
print('num_heads', NUM_HEADS)
UNITS =  2048
DROPOUT = 0.1 #0.1
TIME_STEPS= X_train.shape[1]
print('TIME STEPS', TIME_STEPS)
OUTPUT_SIZE=1
batch_size=64

model = transformer(
  time_steps=TIME_STEPS,
  num_layers=NUM_LAYERS,
  units=UNITS,
  d_model=D_MODEL,
  num_heads=NUM_HEADS,
  dropout=DROPOUT,
  output_size=OUTPUT_SIZE,
  projection='linear')

#run
# model.compile(optimizer=tf.keras.optimizers.Adam(0.00005), loss='mae') #org
model.compile(optimizer=tf.keras.optimizers.Adam(0.000003), loss='mse')
# model.compile(optimizer=tf.keras.optimizers.SGD(0.01), loss='mae')
#
# callback = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience=80, restore_best_weights=True)
# history = model.fit(X_train,Y_train, epochs=1000, validation_data=(X_val, Y_val), callbacks=[callback])
history = model.fit(X_train,Y_train, epochs=1000, validation_data=(X_val, Y_val))
# Out:
# 1
# (1660, 1, 176)
# d_model 176
# num_heads 4
# TIME STEPS 1
# linear
# 2023-10-15 16:28:29.583018: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2211] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# KerasTensor(type_spec=TensorSpec(shape=(None, 1, 1, None), dtype=tf.float32, name='padding_mask'), name='padding_mask', description="created by layer 'padding_mask'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1, 1, None), dtype=tf.float32, name='padding_mask'), name='padding_mask', description="created by layer 'padding_mask'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1, 1, None), dtype=tf.float32, name='padding_mask'), name='padding_mask', description="created by layer 'padding_mask'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1, 1, None), dtype=tf.float32, name='padding_mask'), name='padding_mask', description="created by layer 'padding_mask'")
# Epoch 1/1000
# 52/52 [==============================] - 20s 65ms/step - loss: 6.3328 - val_loss: 2.8666
# Epoch 2/1000
# 52/52 [==============================] - 2s 29ms/step - loss: 2.4306 - val_loss: 2.1631
# Epoch 3/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 2.2113 - val_loss: 1.9573
# Epoch 4/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 2.0224 - val_loss: 1.7283
# Epoch 5/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.9417 - val_loss: 1.7597
# Epoch 6/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.8526 - val_loss: 1.5595
# Epoch 7/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.7873 - val_loss: 1.4962
# Epoch 8/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.7304 - val_loss: 1.4810
# Epoch 9/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.6575 - val_loss: 1.3985
# Epoch 10/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.6785 - val_loss: 1.3747
# Epoch 11/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.6559 - val_loss: 1.3485
# Epoch 12/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.6144 - val_loss: 1.3628
# Epoch 13/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.5553 - val_loss: 1.4073
# Epoch 14/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.5828 - val_loss: 1.2901
# Epoch 15/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.5275 - val_loss: 1.3470
# Epoch 16/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.4770 - val_loss: 1.2567
# Epoch 17/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.4810 - val_loss: 1.2304
# Epoch 18/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.4595 - val_loss: 1.3070
# Epoch 19/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.4984 - val_loss: 1.2128
# Epoch 20/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.4510 - val_loss: 1.2751
# Epoch 21/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.4520 - val_loss: 1.2707
# Epoch 22/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.4450 - val_loss: 1.2019
# Epoch 23/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.4558 - val_loss: 1.2361
# Epoch 24/1000
# 52/52 [==============================] - 1s 28ms/step - loss: 1.3898 - val_loss: 1.1956
# Epoch 25/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.4343 - val_loss: 1.1887
# Epoch 26/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.3762 - val_loss: 1.1674
# Epoch 27/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.3434 - val_loss: 1.1543
# Epoch 28/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.3929 - val_loss: 1.1407
# Epoch 29/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.3277 - val_loss: 1.1739
# Epoch 30/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.3755 - val_loss: 1.1080
# Epoch 31/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.3295 - val_loss: 1.1297
# Epoch 32/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.2794 - val_loss: 1.1743
# Epoch 33/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.3183 - val_loss: 1.1728
# Epoch 34/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.3244 - val_loss: 1.1406
# Epoch 35/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.2776 - val_loss: 1.0903
# Epoch 36/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.3108 - val_loss: 1.0700
# Epoch 37/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.3346 - val_loss: 1.0722
# Epoch 38/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.2530 - val_loss: 1.0538
# Epoch 39/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.2743 - val_loss: 1.1234
# Epoch 40/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.2653 - val_loss: 1.0962
# Epoch 41/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.2647 - val_loss: 1.0870
# Epoch 42/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.2405 - val_loss: 1.0512
# Epoch 43/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.3075 - val_loss: 1.0435
# Epoch 44/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.2845 - val_loss: 1.0469
# Epoch 45/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.2337 - val_loss: 1.0892
# Epoch 46/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.2473 - val_loss: 1.0844
# Epoch 47/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.2893 - val_loss: 1.0354
# Epoch 48/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.1944 - val_loss: 1.0409
# Epoch 49/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.2490 - val_loss: 1.0666
# Epoch 50/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.1939 - val_loss: 1.0645
# Epoch 51/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.1941 - val_loss: 1.0212
# Epoch 52/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.2048 - val_loss: 1.0372
# Epoch 53/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.1898 - val_loss: 1.0658
# Epoch 54/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.1988 - val_loss: 1.0355
# Epoch 55/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.1669 - val_loss: 1.0234
# Epoch 56/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.1401 - val_loss: 1.0222
# Epoch 57/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.1767 - val_loss: 1.0266
# Epoch 58/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.1554 - val_loss: 0.9984
# Epoch 59/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.1706 - val_loss: 1.0523
# Epoch 60/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.1401 - val_loss: 1.0023
# Epoch 61/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.1612 - val_loss: 1.0291
# Epoch 62/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.1513 - val_loss: 1.0166
# Epoch 63/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.1970 - val_loss: 0.9984
# Epoch 64/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.1235 - val_loss: 0.9762
# Epoch 65/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.1721 - val_loss: 1.0017
# Epoch 66/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.1757 - val_loss: 0.9918
# Epoch 67/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.1148 - val_loss: 1.0294
# Epoch 68/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 1.1158 - val_loss: 0.9728
# Epoch 69/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.1167 - val_loss: 0.9727
# Epoch 70/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.1408 - val_loss: 0.9909
# Epoch 71/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.1019 - val_loss: 1.0039
# Epoch 72/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.1332 - val_loss: 0.9573
# Epoch 73/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.0829 - val_loss: 0.9842
# Epoch 74/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.0841 - val_loss: 0.9765
# Epoch 75/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.0701 - val_loss: 0.9792
# Epoch 76/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.0938 - val_loss: 0.9479
# Epoch 77/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 1.0697 - val_loss: 0.9358
# Epoch 78/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.1067 - val_loss: 0.9852
# Epoch 79/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.1052 - val_loss: 0.9275
# Epoch 80/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.0519 - val_loss: 0.9391
# Epoch 81/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.0902 - val_loss: 0.9541
# Epoch 82/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.0637 - val_loss: 0.9679
# Epoch 83/1000
# 52/52 [==============================] - 1s 28ms/step - loss: 1.0784 - val_loss: 0.9405
# Epoch 84/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.0455 - val_loss: 0.9278
# Epoch 85/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.0509 - val_loss: 0.9505
# Epoch 86/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.0278 - val_loss: 0.9427
# Epoch 87/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.0593 - val_loss: 0.9377
# Epoch 88/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.0616 - val_loss: 0.9200
# Epoch 89/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.0784 - val_loss: 0.9147
# Epoch 90/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.0071 - val_loss: 0.9221
# Epoch 91/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.0405 - val_loss: 0.9105
# Epoch 92/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.0309 - val_loss: 0.9314
# Epoch 93/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.0333 - val_loss: 0.9213
# Epoch 94/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.9952 - val_loss: 0.9277
# Epoch 95/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.0069 - val_loss: 0.9258
# Epoch 96/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.0194 - val_loss: 0.9260
# Epoch 97/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.9957 - val_loss: 0.9145
# Epoch 98/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.0330 - val_loss: 0.9175
# Epoch 99/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.9848 - val_loss: 0.9031
# Epoch 100/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.0015 - val_loss: 0.9102
# Epoch 101/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.0519 - val_loss: 0.8992
# Epoch 102/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.9964 - val_loss: 0.9043
# Epoch 103/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.0235 - val_loss: 0.8901
# Epoch 104/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.0287 - val_loss: 0.9078
# Epoch 105/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.0102 - val_loss: 0.8850
# Epoch 106/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 1.0149 - val_loss: 0.8924
# Epoch 107/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.9820 - val_loss: 0.8843
# Epoch 108/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 1.0157 - val_loss: 0.8967
# Epoch 109/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.9786 - val_loss: 0.8881
# Epoch 110/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.9944 - val_loss: 0.8822
# Epoch 111/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.9643 - val_loss: 0.8793
# Epoch 112/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.9765 - val_loss: 0.8793
# Epoch 113/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.9227 - val_loss: 0.8987
# Epoch 114/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.9601 - val_loss: 0.8734
# Epoch 115/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.9642 - val_loss: 0.8799
# Epoch 116/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.9772 - val_loss: 0.8939
# Epoch 117/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.9401 - val_loss: 0.8629
# Epoch 118/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.9797 - val_loss: 0.8805
# Epoch 119/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.9654 - val_loss: 0.8792
# Epoch 120/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.9629 - val_loss: 0.8708
# Epoch 121/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.9538 - val_loss: 0.8671
# Epoch 122/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.9461 - val_loss: 0.8640
# Epoch 123/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.9825 - val_loss: 0.8715
# Epoch 124/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.9423 - val_loss: 0.8790
# Epoch 125/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.9315 - val_loss: 0.8852
# Epoch 126/1000
# 52/52 [==============================] - 1s 28ms/step - loss: 0.9369 - val_loss: 0.8802
# Epoch 127/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.9149 - val_loss: 0.8602
# Epoch 128/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.9068 - val_loss: 0.8550
# Epoch 129/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.9014 - val_loss: 0.8735
# Epoch 130/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.9587 - val_loss: 0.8490
# Epoch 131/1000
# 52/52 [==============================] - 1s 28ms/step - loss: 0.9571 - val_loss: 0.8439
# Epoch 132/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.9116 - val_loss: 0.8641
# Epoch 133/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.9250 - val_loss: 0.8532
# Epoch 134/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.9075 - val_loss: 0.8458
# Epoch 135/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.9479 - val_loss: 0.8486
# Epoch 136/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.9209 - val_loss: 0.8449
# Epoch 137/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.9002 - val_loss: 0.8382
# Epoch 138/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.9043 - val_loss: 0.8498
# Epoch 139/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.9086 - val_loss: 0.8543
# Epoch 140/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.9032 - val_loss: 0.8557
# Epoch 141/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.9138 - val_loss: 0.8430
# Epoch 142/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.9198 - val_loss: 0.8436
# Epoch 143/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.9069 - val_loss: 0.8522
# Epoch 144/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.8629 - val_loss: 0.8512
# Epoch 145/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.9030 - val_loss: 0.8424
# Epoch 146/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.8662 - val_loss: 0.8527
# Epoch 147/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8701 - val_loss: 0.8641
# Epoch 148/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.9123 - val_loss: 0.8457
# Epoch 149/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.9132 - val_loss: 0.8228
# Epoch 150/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.8908 - val_loss: 0.8270
# Epoch 151/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8860 - val_loss: 0.8355
# Epoch 152/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8773 - val_loss: 0.8451
# Epoch 153/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.9006 - val_loss: 0.8329
# Epoch 154/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8737 - val_loss: 0.8379
# Epoch 155/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.8610 - val_loss: 0.8431
# Epoch 156/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.8533 - val_loss: 0.8383
# Epoch 157/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8793 - val_loss: 0.8290
# Epoch 158/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.8729 - val_loss: 0.8341
# Epoch 159/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8561 - val_loss: 0.8314
# Epoch 160/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8492 - val_loss: 0.8320
# Epoch 161/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8339 - val_loss: 0.8284
# Epoch 162/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8524 - val_loss: 0.8623
# Epoch 163/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8558 - val_loss: 0.8360
# Epoch 164/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8703 - val_loss: 0.8402
# Epoch 165/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8821 - val_loss: 0.8232
# Epoch 166/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8655 - val_loss: 0.8433
# Epoch 167/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.8248 - val_loss: 0.8315
# Epoch 168/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8617 - val_loss: 0.8270
# Epoch 169/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.8271 - val_loss: 0.8249
# Epoch 170/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8368 - val_loss: 0.8295
# Epoch 171/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8296 - val_loss: 0.8652
# Epoch 172/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8510 - val_loss: 0.8210
# Epoch 173/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.8347 - val_loss: 0.8174
# Epoch 174/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.8381 - val_loss: 0.8130
# Epoch 175/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8357 - val_loss: 0.8140
# Epoch 176/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.8350 - val_loss: 0.8241
# Epoch 177/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.8580 - val_loss: 0.8150
# Epoch 178/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8241 - val_loss: 0.8132
# Epoch 179/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.8154 - val_loss: 0.8034
# Epoch 180/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8048 - val_loss: 0.8064
# Epoch 181/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8198 - val_loss: 0.7962
# Epoch 182/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.8092 - val_loss: 0.8019
# Epoch 183/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8484 - val_loss: 0.8034
# Epoch 184/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8316 - val_loss: 0.8205
# Epoch 185/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.8110 - val_loss: 0.8111
# Epoch 186/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.8290 - val_loss: 0.7920
# Epoch 187/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8374 - val_loss: 0.7928
# Epoch 188/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8044 - val_loss: 0.8001
# Epoch 189/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7996 - val_loss: 0.7969
# Epoch 190/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8031 - val_loss: 0.7961
# Epoch 191/1000
# 52/52 [==============================] - 1s 28ms/step - loss: 0.8312 - val_loss: 0.8174
# Epoch 192/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8008 - val_loss: 0.7948
# Epoch 193/1000
# 52/52 [==============================] - 1s 28ms/step - loss: 0.7956 - val_loss: 0.8051
# Epoch 194/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8080 - val_loss: 0.7952
# Epoch 195/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7918 - val_loss: 0.8005
# Epoch 196/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7903 - val_loss: 0.7913
# Epoch 197/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7745 - val_loss: 0.7908
# Epoch 198/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.7986 - val_loss: 0.7899
# Epoch 199/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7840 - val_loss: 0.7868
# Epoch 200/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.7959 - val_loss: 0.7887
# Epoch 201/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7825 - val_loss: 0.7911
# Epoch 202/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7661 - val_loss: 0.7908
# Epoch 203/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.8027 - val_loss: 0.7840
# Epoch 204/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7681 - val_loss: 0.7777
# Epoch 205/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7764 - val_loss: 0.7716
# Epoch 206/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7947 - val_loss: 0.7800
# Epoch 207/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7560 - val_loss: 0.7794
# Epoch 208/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.7862 - val_loss: 0.7748
# Epoch 209/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7805 - val_loss: 0.7744
# Epoch 210/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.7470 - val_loss: 0.7873
# Epoch 211/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7638 - val_loss: 0.7810
# Epoch 212/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7627 - val_loss: 0.8083
# Epoch 213/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7418 - val_loss: 0.7965
# Epoch 214/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.7618 - val_loss: 0.7974
# Epoch 215/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7559 - val_loss: 0.7923
# Epoch 216/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7720 - val_loss: 0.7885
# Epoch 217/1000
# 52/52 [==============================] - 1s 28ms/step - loss: 0.7499 - val_loss: 0.7673
# Epoch 218/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7629 - val_loss: 0.7871
# Epoch 219/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7388 - val_loss: 0.7853
# Epoch 220/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7326 - val_loss: 0.7784
# Epoch 221/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7550 - val_loss: 0.7832
# Epoch 222/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.7203 - val_loss: 0.7819
# Epoch 223/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7550 - val_loss: 0.7799
# Epoch 224/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7687 - val_loss: 0.7866
# Epoch 225/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7620 - val_loss: 0.7881
# Epoch 226/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7695 - val_loss: 0.7945
# Epoch 227/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7355 - val_loss: 0.7777
# Epoch 228/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7525 - val_loss: 0.7622
# Epoch 229/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7554 - val_loss: 0.7608
# Epoch 230/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7241 - val_loss: 0.7625
# Epoch 231/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7324 - val_loss: 0.7771
# Epoch 232/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7503 - val_loss: 0.7746
# Epoch 233/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7659 - val_loss: 0.7569
# Epoch 234/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7358 - val_loss: 0.7531
# Epoch 235/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7389 - val_loss: 0.7874
# Epoch 236/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7112 - val_loss: 0.7514
# Epoch 237/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7475 - val_loss: 0.7722
# Epoch 238/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.7385 - val_loss: 0.7616
# Epoch 239/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7315 - val_loss: 0.7726
# Epoch 240/1000
# 52/52 [==============================] - 1s 28ms/step - loss: 0.7413 - val_loss: 0.7645
# Epoch 241/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7521 - val_loss: 0.7567
# Epoch 242/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7444 - val_loss: 0.7591
# Epoch 243/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7385 - val_loss: 0.7707
# Epoch 244/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7116 - val_loss: 0.7447
# Epoch 245/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7315 - val_loss: 0.7537
# Epoch 246/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7231 - val_loss: 0.7663
# Epoch 247/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7330 - val_loss: 0.7424
# Epoch 248/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.7285 - val_loss: 0.7456
# Epoch 249/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7302 - val_loss: 0.7565
# Epoch 250/1000
# 52/52 [==============================] - 1s 28ms/step - loss: 0.7058 - val_loss: 0.7649
# Epoch 251/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6733 - val_loss: 0.7583
# Epoch 252/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7245 - val_loss: 0.7529
# Epoch 253/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7007 - val_loss: 0.7609
# Epoch 254/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7180 - val_loss: 0.7647
# Epoch 255/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6918 - val_loss: 0.7563
# Epoch 256/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7260 - val_loss: 0.7547
# Epoch 257/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6758 - val_loss: 0.7591
# Epoch 258/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7425 - val_loss: 0.7548
# Epoch 259/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7052 - val_loss: 0.7569
# Epoch 260/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7125 - val_loss: 0.7899
# Epoch 261/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7104 - val_loss: 0.7586
# Epoch 262/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6738 - val_loss: 0.7679
# Epoch 263/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6957 - val_loss: 0.7566
# Epoch 264/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7101 - val_loss: 0.7599
# Epoch 265/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6870 - val_loss: 0.7573
# Epoch 266/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7082 - val_loss: 0.7487
# Epoch 267/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6723 - val_loss: 0.7794
# Epoch 268/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.6683 - val_loss: 0.7486
# Epoch 269/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6750 - val_loss: 0.7427
# Epoch 270/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6794 - val_loss: 0.7578
# Epoch 271/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.6829 - val_loss: 0.7672
# Epoch 272/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6874 - val_loss: 0.7534
# Epoch 273/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6647 - val_loss: 0.7588
# Epoch 274/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.7160 - val_loss: 0.7467
# Epoch 275/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.7094 - val_loss: 0.7594
# Epoch 276/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6686 - val_loss: 0.7449
# Epoch 277/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6620 - val_loss: 0.7500
# Epoch 278/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6590 - val_loss: 0.7496
# Epoch 279/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6404 - val_loss: 0.7549
# Epoch 280/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6857 - val_loss: 0.7430
# Epoch 281/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6593 - val_loss: 0.7465
# Epoch 282/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6752 - val_loss: 0.7464
# Epoch 283/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.6853 - val_loss: 0.7593
# Epoch 284/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6819 - val_loss: 0.7488
# Epoch 285/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6724 - val_loss: 0.7391
# Epoch 286/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6874 - val_loss: 0.7365
# Epoch 287/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6637 - val_loss: 0.7289
# Epoch 288/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6370 - val_loss: 0.7571
# Epoch 289/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6798 - val_loss: 0.7345
# Epoch 290/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6759 - val_loss: 0.7348
# Epoch 291/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6578 - val_loss: 0.7470
# Epoch 292/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6511 - val_loss: 0.7464
# Epoch 293/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6661 - val_loss: 0.7427
# Epoch 294/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6638 - val_loss: 0.7414
# Epoch 295/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.6665 - val_loss: 0.7587
# Epoch 296/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6418 - val_loss: 0.7397
# Epoch 297/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6774 - val_loss: 0.7448
# Epoch 298/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6321 - val_loss: 0.7421
# Epoch 299/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6681 - val_loss: 0.7343
# Epoch 300/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6638 - val_loss: 0.7320
# Epoch 301/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6576 - val_loss: 0.7437
# Epoch 302/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6364 - val_loss: 0.7501
# Epoch 303/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.6603 - val_loss: 0.7350
# Epoch 304/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6317 - val_loss: 0.7509
# Epoch 305/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.6533 - val_loss: 0.7496
# Epoch 306/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.6311 - val_loss: 0.7369
# Epoch 307/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6436 - val_loss: 0.7266
# Epoch 308/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.6340 - val_loss: 0.7434
# Epoch 309/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.6321 - val_loss: 0.7347
# Epoch 310/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.6508 - val_loss: 0.7350
# Epoch 311/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6640 - val_loss: 0.7330
# Epoch 312/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6264 - val_loss: 0.7374
# Epoch 313/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6565 - val_loss: 0.7342
# Epoch 314/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.6270 - val_loss: 0.7313
# Epoch 315/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.6304 - val_loss: 0.7202
# Epoch 316/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6231 - val_loss: 0.7302
# Epoch 317/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6459 - val_loss: 0.7200
# Epoch 318/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.6651 - val_loss: 0.7466
# Epoch 319/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6383 - val_loss: 0.7357
# Epoch 320/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6358 - val_loss: 0.7356
# Epoch 321/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6206 - val_loss: 0.7220
# Epoch 322/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6255 - val_loss: 0.7268
# Epoch 323/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6332 - val_loss: 0.7236
# Epoch 324/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.6445 - val_loss: 0.7277
# Epoch 325/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6117 - val_loss: 0.7363
# Epoch 326/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6254 - val_loss: 0.7306
# Epoch 327/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6038 - val_loss: 0.7414
# Epoch 328/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6453 - val_loss: 0.7305
# Epoch 329/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.6189 - val_loss: 0.7407
# Epoch 330/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6315 - val_loss: 0.7279
# Epoch 331/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6252 - val_loss: 0.7363
# Epoch 332/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6439 - val_loss: 0.7271
# Epoch 333/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6371 - val_loss: 0.7292
# Epoch 334/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6117 - val_loss: 0.7187
# Epoch 335/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6070 - val_loss: 0.7320
# Epoch 336/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6398 - val_loss: 0.7173
# Epoch 337/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6164 - val_loss: 0.7289
# Epoch 338/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.6048 - val_loss: 0.7230
# Epoch 339/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6146 - val_loss: 0.7215
# Epoch 340/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.6201 - val_loss: 0.7370
# Epoch 341/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5954 - val_loss: 0.7370
# Epoch 342/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5852 - val_loss: 0.7436
# Epoch 343/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.6320 - val_loss: 0.7335
# Epoch 344/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.6146 - val_loss: 0.7314
# Epoch 345/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6074 - val_loss: 0.7327
# Epoch 346/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5932 - val_loss: 0.7177
# Epoch 347/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6162 - val_loss: 0.7314
# Epoch 348/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5922 - val_loss: 0.7218
# Epoch 349/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6132 - val_loss: 0.7260
# Epoch 350/1000
# 52/52 [==============================] - 1s 28ms/step - loss: 0.5903 - val_loss: 0.7431
# Epoch 351/1000
# 52/52 [==============================] - 1s 28ms/step - loss: 0.5734 - val_loss: 0.7257
# Epoch 352/1000
# 52/52 [==============================] - 1s 28ms/step - loss: 0.6078 - val_loss: 0.7184
# Epoch 353/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5842 - val_loss: 0.7197
# Epoch 354/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6019 - val_loss: 0.7161
# Epoch 355/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5722 - val_loss: 0.7379
# Epoch 356/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5851 - val_loss: 0.7226
# Epoch 357/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5696 - val_loss: 0.7190
# Epoch 358/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5955 - val_loss: 0.7175
# Epoch 359/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5815 - val_loss: 0.7155
# Epoch 360/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.6086 - val_loss: 0.7217
# Epoch 361/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5986 - val_loss: 0.7499
# Epoch 362/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5934 - val_loss: 0.7242
# Epoch 363/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5959 - val_loss: 0.7160
# Epoch 364/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5730 - val_loss: 0.7206
# Epoch 365/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5789 - val_loss: 0.7166
# Epoch 366/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5741 - val_loss: 0.7258
# Epoch 367/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5859 - val_loss: 0.7424
# Epoch 368/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5897 - val_loss: 0.7258
# Epoch 369/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5962 - val_loss: 0.7246
# Epoch 370/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.5773 - val_loss: 0.7235
# Epoch 371/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5798 - val_loss: 0.7302
# Epoch 372/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5678 - val_loss: 0.7203
# Epoch 373/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5822 - val_loss: 0.7177
# Epoch 374/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5790 - val_loss: 0.7366
# Epoch 375/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5838 - val_loss: 0.7266
# Epoch 376/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5784 - val_loss: 0.7219
# Epoch 377/1000
# 52/52 [==============================] - 1s 28ms/step - loss: 0.5834 - val_loss: 0.7348
# Epoch 378/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5840 - val_loss: 0.7196
# Epoch 379/1000
# 52/52 [==============================] - 1s 28ms/step - loss: 0.5874 - val_loss: 0.7216
# Epoch 380/1000
# 52/52 [==============================] - 1s 28ms/step - loss: 0.5797 - val_loss: 0.7179
# Epoch 381/1000
# 52/52 [==============================] - 1s 28ms/step - loss: 0.5837 - val_loss: 0.7177
# Epoch 382/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5598 - val_loss: 0.7215
# Epoch 383/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5752 - val_loss: 0.7151
# Epoch 384/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5694 - val_loss: 0.7141
# Epoch 385/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5587 - val_loss: 0.7347
# Epoch 386/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5829 - val_loss: 0.7170
# Epoch 387/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5577 - val_loss: 0.7066
# Epoch 388/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5956 - val_loss: 0.7076
# Epoch 389/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5934 - val_loss: 0.7117
# Epoch 390/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5495 - val_loss: 0.7156
# Epoch 391/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5757 - val_loss: 0.7178
# Epoch 392/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5646 - val_loss: 0.7142
# Epoch 393/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5849 - val_loss: 0.7132
# Epoch 394/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5572 - val_loss: 0.7094
# Epoch 395/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5571 - val_loss: 0.7129
# Epoch 396/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5753 - val_loss: 0.7202
# Epoch 397/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5649 - val_loss: 0.7123
# Epoch 398/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5703 - val_loss: 0.7101
# Epoch 399/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5626 - val_loss: 0.6990
# Epoch 400/1000
# 52/52 [==============================] - 1s 28ms/step - loss: 0.5658 - val_loss: 0.7161
# Epoch 401/1000
# 52/52 [==============================] - 1s 28ms/step - loss: 0.5637 - val_loss: 0.7236
# Epoch 402/1000
# 52/52 [==============================] - 1s 28ms/step - loss: 0.5669 - val_loss: 0.7223
# Epoch 403/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5460 - val_loss: 0.7022
# Epoch 404/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5245 - val_loss: 0.7046
# Epoch 405/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5552 - val_loss: 0.7003
# Epoch 406/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5612 - val_loss: 0.6999
# Epoch 407/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5679 - val_loss: 0.7205
# Epoch 408/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5585 - val_loss: 0.7013
# Epoch 409/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5675 - val_loss: 0.7030
# Epoch 410/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5669 - val_loss: 0.6974
# Epoch 411/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5511 - val_loss: 0.7182
# Epoch 412/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5479 - val_loss: 0.7074
# Epoch 413/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5573 - val_loss: 0.7030
# Epoch 414/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5455 - val_loss: 0.7189
# Epoch 415/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5353 - val_loss: 0.7210
# Epoch 416/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5515 - val_loss: 0.7091
# Epoch 417/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5502 - val_loss: 0.7111
# Epoch 418/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5502 - val_loss: 0.7177
# Epoch 419/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5444 - val_loss: 0.7004
# Epoch 420/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5596 - val_loss: 0.7059
# Epoch 421/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5385 - val_loss: 0.7002
# Epoch 422/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5370 - val_loss: 0.7092
# Epoch 423/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5378 - val_loss: 0.6963
# Epoch 424/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5491 - val_loss: 0.7190
# Epoch 425/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5178 - val_loss: 0.7141
# Epoch 426/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5339 - val_loss: 0.7131
# Epoch 427/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5336 - val_loss: 0.7153
# Epoch 428/1000
# 52/52 [==============================] - 1s 28ms/step - loss: 0.5556 - val_loss: 0.7180
# Epoch 429/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5260 - val_loss: 0.7253
# Epoch 430/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5245 - val_loss: 0.7126
# Epoch 431/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5384 - val_loss: 0.7047
# Epoch 432/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5334 - val_loss: 0.7093
# Epoch 433/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5310 - val_loss: 0.7050
# Epoch 434/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5451 - val_loss: 0.7210
# Epoch 435/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5418 - val_loss: 0.7149
# Epoch 436/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5289 - val_loss: 0.7033
# Epoch 437/1000
# 52/52 [==============================] - 1s 28ms/step - loss: 0.5167 - val_loss: 0.7135
# Epoch 438/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5477 - val_loss: 0.7245
# Epoch 439/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5064 - val_loss: 0.7102
# Epoch 440/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5045 - val_loss: 0.7236
# Epoch 441/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5018 - val_loss: 0.7087
# Epoch 442/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5385 - val_loss: 0.7207
# Epoch 443/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5380 - val_loss: 0.7064
# Epoch 444/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5326 - val_loss: 0.7023
# Epoch 445/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.5210 - val_loss: 0.7079
# Epoch 446/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5467 - val_loss: 0.7028
# Epoch 447/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5099 - val_loss: 0.7125
# Epoch 448/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5077 - val_loss: 0.7022
# Epoch 449/1000
# 52/52 [==============================] - 1s 28ms/step - loss: 0.5311 - val_loss: 0.7020
# Epoch 450/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5399 - val_loss: 0.7044
# Epoch 451/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5077 - val_loss: 0.7220
# Epoch 452/1000
# 52/52 [==============================] - 1s 28ms/step - loss: 0.5172 - val_loss: 0.7025
# Epoch 453/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5216 - val_loss: 0.7245
# Epoch 454/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5442 - val_loss: 0.6987
# Epoch 455/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5103 - val_loss: 0.7066
# Epoch 456/1000
# 52/52 [==============================] - 1s 27ms/step - loss: 0.5254 - val_loss: 0.7071
# Epoch 457/1000
# ...
# Epoch 846/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3577 - val_loss: 0.7582
# Epoch 847/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3541 - val_loss: 0.7505
# Epoch 848/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3442 - val_loss: 0.7581
# Epoch 849/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3383 - val_loss: 0.7658
# Epoch 850/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3584 - val_loss: 0.7792
# Epoch 851/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3627 - val_loss: 0.7546
# Epoch 852/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3620 - val_loss: 0.7540
# Epoch 853/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3594 - val_loss: 0.7712
# Epoch 854/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3719 - val_loss: 0.7671
# Epoch 855/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3608 - val_loss: 0.7467
# Epoch 856/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3471 - val_loss: 0.7617
# Epoch 857/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3519 - val_loss: 0.7589
# Epoch 858/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3394 - val_loss: 0.7714
# Epoch 859/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3377 - val_loss: 0.7682
# Epoch 860/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3628 - val_loss: 0.7607
# Epoch 861/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3658 - val_loss: 0.7615
# Epoch 862/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3408 - val_loss: 0.7595
# Epoch 863/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3474 - val_loss: 0.7622
# Epoch 864/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3560 - val_loss: 0.7451
# Epoch 865/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3588 - val_loss: 0.7555
# Epoch 866/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3561 - val_loss: 0.7706
# Epoch 867/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3589 - val_loss: 0.7688
# Epoch 868/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3445 - val_loss: 0.7594
# Epoch 869/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3363 - val_loss: 0.7639
# Epoch 870/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3603 - val_loss: 0.7507
# Epoch 871/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3515 - val_loss: 0.7516
# Epoch 872/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3341 - val_loss: 0.7540
# Epoch 873/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3432 - val_loss: 0.7603
# Epoch 874/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3559 - val_loss: 0.7591
# Epoch 875/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3426 - val_loss: 0.7525
# Epoch 876/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3471 - val_loss: 0.7649
# Epoch 877/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3383 - val_loss: 0.7593
# Epoch 878/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3598 - val_loss: 0.7591
# Epoch 879/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3388 - val_loss: 0.7556
# Epoch 880/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3585 - val_loss: 0.7661
# Epoch 881/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3396 - val_loss: 0.7599
# Epoch 882/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3475 - val_loss: 0.7633
# Epoch 883/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3451 - val_loss: 0.7676
# Epoch 884/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3294 - val_loss: 0.7621
# Epoch 885/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3404 - val_loss: 0.7830
# Epoch 886/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3535 - val_loss: 0.7526
# Epoch 887/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3524 - val_loss: 0.7523
# Epoch 888/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3451 - val_loss: 0.7522
# Epoch 889/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3578 - val_loss: 0.7412
# Epoch 890/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3734 - val_loss: 0.7539
# Epoch 891/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3360 - val_loss: 0.7612
# Epoch 892/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3590 - val_loss: 0.7630
# Epoch 893/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3488 - val_loss: 0.7650
# Epoch 894/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3478 - val_loss: 0.7596
# Epoch 895/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3466 - val_loss: 0.7796
# Epoch 896/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3418 - val_loss: 0.7637
# Epoch 897/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3434 - val_loss: 0.7664
# Epoch 898/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3303 - val_loss: 0.7677
# Epoch 899/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3426 - val_loss: 0.7664
# Epoch 900/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3393 - val_loss: 0.7623
# Epoch 901/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3470 - val_loss: 0.7583
# Epoch 902/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3468 - val_loss: 0.7619
# Epoch 903/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3322 - val_loss: 0.7652
# Epoch 904/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3446 - val_loss: 0.7592
# Epoch 905/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3358 - val_loss: 0.7718
# Epoch 906/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3381 - val_loss: 0.7722
# Epoch 907/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3522 - val_loss: 0.7616
# Epoch 908/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3510 - val_loss: 0.7546
# Epoch 909/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3357 - val_loss: 0.7694
# Epoch 910/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3286 - val_loss: 0.7602
# Epoch 911/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3287 - val_loss: 0.7642
# Epoch 912/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3493 - val_loss: 0.7498
# Epoch 913/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3335 - val_loss: 0.7638
# Epoch 914/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3426 - val_loss: 0.7636
# Epoch 915/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3464 - val_loss: 0.7695
# Epoch 916/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3399 - val_loss: 0.7650
# Epoch 917/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3470 - val_loss: 0.7588
# Epoch 918/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3361 - val_loss: 0.7767
# Epoch 919/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3360 - val_loss: 0.7733
# Epoch 920/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3327 - val_loss: 0.7717
# Epoch 921/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3411 - val_loss: 0.7583
# Epoch 922/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3412 - val_loss: 0.7670
# Epoch 923/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3463 - val_loss: 0.7661
# Epoch 924/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3402 - val_loss: 0.7741
# Epoch 925/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3373 - val_loss: 0.7625
# Epoch 926/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3224 - val_loss: 0.7618
# Epoch 927/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3386 - val_loss: 0.7678
# Epoch 928/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3390 - val_loss: 0.7666
# Epoch 929/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3485 - val_loss: 0.7555
# Epoch 930/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3261 - val_loss: 0.7716
# Epoch 931/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3372 - val_loss: 0.7634
# Epoch 932/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3311 - val_loss: 0.7514
# Epoch 933/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3207 - val_loss: 0.7548
# Epoch 934/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3320 - val_loss: 0.7762
# Epoch 935/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3528 - val_loss: 0.7605
# Epoch 936/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3364 - val_loss: 0.7651
# Epoch 937/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3306 - val_loss: 0.7662
# Epoch 938/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3377 - val_loss: 0.7621
# Epoch 939/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3311 - val_loss: 0.7632
# Epoch 940/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3209 - val_loss: 0.7690
# Epoch 941/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3296 - val_loss: 0.7839
# Epoch 942/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3220 - val_loss: 0.7745
# Epoch 943/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3239 - val_loss: 0.7806
# Epoch 944/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3367 - val_loss: 0.7708
# Epoch 945/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3505 - val_loss: 0.7492
# Epoch 946/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3363 - val_loss: 0.7604
# Epoch 947/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3189 - val_loss: 0.7644
# Epoch 948/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3138 - val_loss: 0.7650
# Epoch 949/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3244 - val_loss: 0.7640
# Epoch 950/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3324 - val_loss: 0.7791
# Epoch 951/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3232 - val_loss: 0.7629
# Epoch 952/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3373 - val_loss: 0.7664
# Epoch 953/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3394 - val_loss: 0.7729
# Epoch 954/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3171 - val_loss: 0.7534
# Epoch 955/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3247 - val_loss: 0.7625
# Epoch 956/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3292 - val_loss: 0.7587
# Epoch 957/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3291 - val_loss: 0.7542
# Epoch 958/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3301 - val_loss: 0.7577
# Epoch 959/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3334 - val_loss: 0.7566
# Epoch 960/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3369 - val_loss: 0.7581
# Epoch 961/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3404 - val_loss: 0.7450
# Epoch 962/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3162 - val_loss: 0.7484
# Epoch 963/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3274 - val_loss: 0.7573
# Epoch 964/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3228 - val_loss: 0.7797
# Epoch 965/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3372 - val_loss: 0.7638
# Epoch 966/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3258 - val_loss: 0.7657
# Epoch 967/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3352 - val_loss: 0.7596
# Epoch 968/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3257 - val_loss: 0.7616
# Epoch 969/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3253 - val_loss: 0.7649
# Epoch 970/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3132 - val_loss: 0.7662
# Epoch 971/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3223 - val_loss: 0.7746
# Epoch 972/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3324 - val_loss: 0.7582
# Epoch 973/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3222 - val_loss: 0.7550
# Epoch 974/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3152 - val_loss: 0.7572
# Epoch 975/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3178 - val_loss: 0.7817
# Epoch 976/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3243 - val_loss: 0.7737
# Epoch 977/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3212 - val_loss: 0.7669
# Epoch 978/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3281 - val_loss: 0.7678
# Epoch 979/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3191 - val_loss: 0.7771
# Epoch 980/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3114 - val_loss: 0.7753
# Epoch 981/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3164 - val_loss: 0.7787
# Epoch 982/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3231 - val_loss: 0.7890
# Epoch 983/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3185 - val_loss: 0.7533
# Epoch 984/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3162 - val_loss: 0.7704
# Epoch 985/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3064 - val_loss: 0.7619
# Epoch 986/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3315 - val_loss: 0.7682
# Epoch 987/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3166 - val_loss: 0.7747
# Epoch 988/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3368 - val_loss: 0.7761
# Epoch 989/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3189 - val_loss: 0.7628
# Epoch 990/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3171 - val_loss: 0.7845
# Epoch 991/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3117 - val_loss: 0.7767
# Epoch 992/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3239 - val_loss: 0.7665
# Epoch 993/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3396 - val_loss: 0.7563
# Epoch 994/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3035 - val_loss: 0.7773
# Epoch 995/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3098 - val_loss: 0.7754
# Epoch 996/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3347 - val_loss: 0.7687
# Epoch 997/1000
# 52/52 [==============================] - 1s 25ms/step - loss: 0.3252 - val_loss: 0.7533
# Epoch 998/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3163 - val_loss: 0.7535
# Epoch 999/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3316 - val_loss: 0.7652
# Epoch 1000/1000
# 52/52 [==============================] - 1s 26ms/step - loss: 0.3192 - val_loss: 0.7629

# %%
#run
import time
st = time.time()
p1 = np.array(model(X_val)).flatten()
end = time.time()
# print(end, st, len(p1))
print((end-st)/len(p1))
p2 = np.array(model(X_train)).flatten()
print(X_train.shape)
print(X_val.shape)
# Out:
# 0.0005130066929093327
# (1660, 1, 176)
# (415, 1, 176)

# %%
from scipy import stats
from scipy.stats import kendalltau
print("training")
print(np.corrcoef(p2, Y_train), stats.spearmanr(p2, Y_train), kendalltau(p2,Y_train).correlation)
print("Validation")
print(np.corrcoef(p1, Y_val)[1][0], stats.spearmanr(p1, Y_val).correlation, kendalltau(p1,Y_val).correlation)
# Out:
# training
# [[1.         0.93807233]
#  [0.93807233 1.        ]] SignificanceResult(statistic=0.934443165650829, pvalue=0.0) 0.7755565098949307
# Validation
# 0.7763186656405803 0.7717128529732311 0.5791537967264561

# %%
X_train.shape
# Out:
# (1660, 1, 176)

# %%
#run
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.savefig("audio_dm_3_featu_.jpg")

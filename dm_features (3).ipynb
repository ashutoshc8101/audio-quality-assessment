# %%
#run
# from google.colab import drive    
# drive.mount('/content/drive')

# %%
#run
# !pip install -Uq spafe

# %%
#run
import pandas as pd
import os
import librosa
import librosa.display
import numpy as np
import IPython.display as ipd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#run
import os
from scipy.io import wavfile

from spafe.utils import vis
from spafe.features.lfcc import lfcc
from spafe.features.pncc import pncc

Main_folder= os.path.join(os.getcwd(), "DatabaseDistorted")
dataset_path= os.path.join(os.getcwd(), "DatabaseDistorted/tii_is_changed_mos1/")
folder_content=(os.listdir(dataset_path))
print(folder_content)
print(len(folder_content))
# Out:
# ['3.21_audio.home_video_8_4.wav', '1.24_audio.tie_tut_1_9.wav', '4.23_audio.___59_____19.wav', '3.96_audio.dive_10.wav', '4.24_audio.train_org4.wav', '4.61_audio.___70_____ps.wav', '2.19_audio.___4_____21.wav', '3.88_audio.___66_____ps.wav', '1.19_audio.implicitDist___420____.wav', '1.76_audio.animation_1_6.wav', '3.01_audio.nature_112_10.wav', '1.96_audio.chair_basketball_4.wav', '4.84_audio.___29____.wav', '3.20_audio.walkway_1_5.wav', '1.00_audio.news_2_7.wav', '3.48_audio.nature_5_3.wav', '1.92_audio.music_22_1.wav', '4.81_audio.boy_dance_org3_1.wav', '2.69_audio.84Output___30____.wav', '4.72_audio.street_dance_2_3.wav', '2.38_audio.boat_1_3.wav', '4.92_audio.girls_song_org.wav', '1.16_audio.music_41_6.wav', '3.07_audio.___23_____ps.wav', '4.16_audio.dance_21_2.wav', '1.41_audio.animation_2_7.wav', '4.92_audio.dance_group_org_1.wav', '2.12_audio.nature_org19_2.wav', '2.46_audio.40Output___15____.wav', '1.32_audio.childrendance_2_7.wav', '4.80_audio.music_13_8.wav', '4.92_audio.music_63_5.wav', '1.08_audio.train_2_10.wav', '1.84_audio.___51_____19.wav', '2.81_audio.chair_basketball_8.wav', '3.42_audio.___3_____13.wav', '1.28_audio.basketball_10.wav', '4.32_audio.animation_2_5.wav', '2.19_audio.implicitDist___336____.wav', '1.00_audio.interview_22_3.wav', '5.00_audio.interview_org41.wav', '2.96_audio.street_dance_2_1.wav', '1.80_audio.___60_____20.wav', '4.76_audio.___17____.wav', '1.02_audio.recipe_1_10.wav', '1.46_audio.___57_____11.wav', '4.82_audio.interview_11_1.wav', '1.12_audio.girls_dance1_9.wav', '2.20_audio.home_video_5_7.wav', '3.69_audio.___39_____13.wav', '3.42_audio.implicitDist___125____.wav', '2.36_audio.dance_22_1.wav', '4.83_audio.home_video_4_2.wav', '4.57_audio.___8_____ps.wav', '2.69_audio.implicitDist___66____.wav', '3.32_audio.animation_12_1.wav', '3.92_audio.___82_____17.wav', '4.72_audio.friends_1_2.wav', '3.64_audio.music_52_2.wav', '4.32_audio.street_dance_org1.wav', '1.16_audio.boxing_2_7.wav', '4.53_audio.___86_____ps.wav', '3.53_audio.implicitDist___53____.wav', '4.42_audio.___89_____ps.wav', '3.61_audio.implicitDist___439____.wav', '4.92_audio.girl_interview_org_2_2.wav', '4.24_audio.music_22_2.wav', '1.46_audio.implicitDist___101____.wav', '4.88_audio.___85____.wav', '1.21_audio.desert_bike_3.wav', '2.20_audio.dance_22_7.wav', '3.04_audio.bike_9.wav', '2.96_audio.home_video_8_3.wav', '1.65_audio.implicitDist___116____.wav', '3.19_audio.implicitDist___220____.wav', '2.38_audio.boxing_1_1_13.wav', '4.42_audio.boy_speaking_1_15.wav', '4.58_audio.animation_2_2.wav', '5.00_audio.animation_9_8.wav', '3.46_audio.guitar_3_12.wav', '3.88_audio.bull_1_4.wav', '2.32_audio.home_video_7_4.wav', '1.84_audio.music_13_7.wav', '4.23_audio.travel_11_2_15.wav', '4.90_audio.snow_org_2_1.wav', '1.32_audio.music_31_4.wav', '2.76_audio.train_org1.wav', '2.26_audio.childrendance_2_13.wav', '4.61_audio.___28_____ps.wav', '4.92_audio.___70____.wav', '4.92_audio.guitar_org5.wav', '4.42_audio.___82_____ps.wav', '3.34_audio.___87_____23.wav', '1.16_audio.nature_13_2.wav', '4.72_audio.car_1_6.wav', '4.19_audio.___63_____ps.wav', '3.40_audio.interview_31_6.wav', '4.73_audio.___90____.wav', '4.08_audio.tie_tut_org1.wav', '4.96_audio.music_org2_2.wav', '2.46_audio.nature_7_2_12.wav', '2.00_audio.street_dance_1_7.wav', '3.03_audio.64Output___30____.wav', '5.00_audio.animation_org2_1.wav', '1.40_audio.boxing_3_2.wav', '3.26_audio.___71_____11.wav', '2.04_audio.people_rush_1_6.wav', '3.26_audio._df____14____.wav', '1.26_audio.implicitDist___320____.wav', '1.24_audio.tunnel_7.wav', '1.64_audio.street_show_2_4.wav', '3.53_audio.___67_____19.wav', '2.88_audio.dance_21_3.wav', '4.92_audio.song_org_4_1.wav', '2.65_audio.group_song_1_1_11.wav', '1.56_audio.travel_org7_3.wav', '2.46_audio.___10_____21.wav', '2.61_audio.___32_____ps.wav', '4.69_audio.___24____.wav', '3.32_audio.street_dance_2_9.wav', '2.30_audio.interview_42_11.wav', '4.76_audio.interview_111_6.wav', '3.04_audio.traffic_1_5.wav', '1.36_audio.travel_org8_3.wav', '1.80_au ...
# 2075

# %%
#run
from spafe.features.bfcc import bfcc
from spafe.features.lpc import lpc, lpcc
from spafe.features.gfcc import gfcc

def chroma_cqt_simple_mean_feature(audio, sample_rate):
  C=librosa.feature.chroma_cqt(y=audio, sr=sample_rate)
  C_mean = np.mean(C.T,axis=0)
  print("size of chroma_cqt_simple_mean_feature", C_mean.shape)

  return C_mean;


def melspectrogram_mean_feature(audio, sample_rate):
  C=librosa.feature.melspectrogram(y=audio, sr=sample_rate)
  C_mean = np.mean(C.T,axis=0)
  print("size of melspectrogram_mean_feature", C_mean.shape)
  return  C_mean;

#MFCC
def mfcc_simple_mean_feature(audio, sample_rate ):
    mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
    mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
    print("size of mfcc_simple_mean_feature", mfccs_scaled_features.shape)
    return mfccs_scaled_features


def spectral_contrast_mean_feature(audio, sample_rate ):
    S = np.abs(librosa.stft(audio))
    contrast = librosa.feature.spectral_contrast(S=S, sr=sample_rate)
    print("size of spectral_contrast_mean_feature", contrast.shape)
    return np.mean(contrast, axis=0)

def spectral_centroid_mean_feature(audio, sample_rate):
    cent = librosa.feature.spectral_centroid(y=audio, sr=sample_rate)
    print("size of spectral_centroid_mean_feature", cent.shape)
    return np.mean(cent, axis=0)

#pncc
def pncc_simple_mean_feature(audio, sample_rate):
  C=pncc(sig=audio, fs=sample_rate);
  C_mean = np.mean(C,axis=0)
  print("size of pncc_simple_mean_feature", C_mean.shape)
  return C_mean;

# %%
# feature_names=["mfcc_simple_mean" , "chroma_simple_mean", "mel_simple_mean"]
feature_names=["spectral_centroid_mean_feature"]

# %%
# #Reading audio file  names and labels
# metadata=pd.read_csv(dataset_path+"seen_unseen_labels.csv")
# metadata.head()

# %%
#run after changing path to the directory containg audios whose features need to be extracted
Files = os.listdir("./DatabaseDistorted/tii_is_changed_mos1/")

# %%
print(len(Files),Files)
# Out:
# 2075 ['3.21_audio.home_video_8_4.wav', '1.24_audio.tie_tut_1_9.wav', '4.23_audio.___59_____19.wav', '3.96_audio.dive_10.wav', '4.24_audio.train_org4.wav', '4.61_audio.___70_____ps.wav', '2.19_audio.___4_____21.wav', '3.88_audio.___66_____ps.wav', '1.19_audio.implicitDist___420____.wav', '1.76_audio.animation_1_6.wav', '3.01_audio.nature_112_10.wav', '1.96_audio.chair_basketball_4.wav', '4.84_audio.___29____.wav', '3.20_audio.walkway_1_5.wav', '1.00_audio.news_2_7.wav', '3.48_audio.nature_5_3.wav', '1.92_audio.music_22_1.wav', '4.81_audio.boy_dance_org3_1.wav', '2.69_audio.84Output___30____.wav', '4.72_audio.street_dance_2_3.wav', '2.38_audio.boat_1_3.wav', '4.92_audio.girls_song_org.wav', '1.16_audio.music_41_6.wav', '3.07_audio.___23_____ps.wav', '4.16_audio.dance_21_2.wav', '1.41_audio.animation_2_7.wav', '4.92_audio.dance_group_org_1.wav', '2.12_audio.nature_org19_2.wav', '2.46_audio.40Output___15____.wav', '1.32_audio.childrendance_2_7.wav', '4.80_audio.music_13_8.wav', '4.92_audio.music_63_5.wav', '1.08_audio.train_2_10.wav', '1.84_audio.___51_____19.wav', '2.81_audio.chair_basketball_8.wav', '3.42_audio.___3_____13.wav', '1.28_audio.basketball_10.wav', '4.32_audio.animation_2_5.wav', '2.19_audio.implicitDist___336____.wav', '1.00_audio.interview_22_3.wav', '5.00_audio.interview_org41.wav', '2.96_audio.street_dance_2_1.wav', '1.80_audio.___60_____20.wav', '4.76_audio.___17____.wav', '1.02_audio.recipe_1_10.wav', '1.46_audio.___57_____11.wav', '4.82_audio.interview_11_1.wav', '1.12_audio.girls_dance1_9.wav', '2.20_audio.home_video_5_7.wav', '3.69_audio.___39_____13.wav', '3.42_audio.implicitDist___125____.wav', '2.36_audio.dance_22_1.wav', '4.83_audio.home_video_4_2.wav', '4.57_audio.___8_____ps.wav', '2.69_audio.implicitDist___66____.wav', '3.32_audio.animation_12_1.wav', '3.92_audio.___82_____17.wav', '4.72_audio.friends_1_2.wav', '3.64_audio.music_52_2.wav', '4.32_audio.street_dance_org1.wav', '1.16_audio.boxing_2_7.wav', '4.53_audio.___86_____ps.wav', '3.53_audio.implicitDist___53____.wav', '4.42_audio.___89_____ps.wav', '3.61_audio.implicitDist___439____.wav', '4.92_audio.girl_interview_org_2_2.wav', '4.24_audio.music_22_2.wav', '1.46_audio.implicitDist___101____.wav', '4.88_audio.___85____.wav', '1.21_audio.desert_bike_3.wav', '2.20_audio.dance_22_7.wav', '3.04_audio.bike_9.wav', '2.96_audio.home_video_8_3.wav', '1.65_audio.implicitDist___116____.wav', '3.19_audio.implicitDist___220____.wav', '2.38_audio.boxing_1_1_13.wav', '4.42_audio.boy_speaking_1_15.wav', '4.58_audio.animation_2_2.wav', '5.00_audio.animation_9_8.wav', '3.46_audio.guitar_3_12.wav', '3.88_audio.bull_1_4.wav', '2.32_audio.home_video_7_4.wav', '1.84_audio.music_13_7.wav', '4.23_audio.travel_11_2_15.wav', '4.90_audio.snow_org_2_1.wav', '1.32_audio.music_31_4.wav', '2.76_audio.train_org1.wav', '2.26_audio.childrendance_2_13.wav', '4.61_audio.___28_____ps.wav', '4.92_audio.___70____.wav', '4.92_audio.guitar_org5.wav', '4.42_audio.___82_____ps.wav', '3.34_audio.___87_____23.wav', '1.16_audio.nature_13_2.wav', '4.72_audio.car_1_6.wav', '4.19_audio.___63_____ps.wav', '3.40_audio.interview_31_6.wav', '4.73_audio.___90____.wav', '4.08_audio.tie_tut_org1.wav', '4.96_audio.music_org2_2.wav', '2.46_audio.nature_7_2_12.wav', '2.00_audio.street_dance_1_7.wav', '3.03_audio.64Output___30____.wav', '5.00_audio.animation_org2_1.wav', '1.40_audio.boxing_3_2.wav', '3.26_audio.___71_____11.wav', '2.04_audio.people_rush_1_6.wav', '3.26_audio._df____14____.wav', '1.26_audio.implicitDist___320____.wav', '1.24_audio.tunnel_7.wav', '1.64_audio.street_show_2_4.wav', '3.53_audio.___67_____19.wav', '2.88_audio.dance_21_3.wav', '4.92_audio.song_org_4_1.wav', '2.65_audio.group_song_1_1_11.wav', '1.56_audio.travel_org7_3.wav', '2.46_audio.___10_____21.wav', '2.61_audio.___32_____ps.wav', '4.69_audio.___24____.wav', '3.32_audio.street_dance_2_9.wav', '2.30_audio.interview_42_11.wav', '4.76_audio.interview_111_6.wav', '3.04_audio.traffic_1_5.wav', '1.36_audio.travel_org8_3.wav', '1. ...

# %%
# for i in Files:
#   if "Output" in i:
#     print(i)
#     Files.remove(i)
# print(Files)

# %%
#run
from collections import defaultdict

#SAVING AUDIO FILES IN CSV

def read_audio_clip(file_name):
    audio,sample_rate = librosa.load(file_name) 
    return audio, sample_rate

Features = defaultdict(list);
import time
st = time.time()
for i in range(0,len(Files)): 
    print("file no:",i)    
    file_name = dataset_path+Files[i]
    print("file_name",file_name)
    quality = float(Files[i][:4]) #add quality score
    audio, sample_rate=read_audio_clip(file_name)
    if(i%100 == 0):
      print('{} data files have been read'.format(i))
    # print(i)
    # print(len(audio))
    # print(sample_rate)
   
    Features['mfcc_simple_mean_new'].append([ mfcc_simple_mean_feature(audio, sample_rate ), quality]);
    Features["chroma_cqt_simple_mean_new"].append([chroma_cqt_simple_mean_feature(audio, sample_rate), quality]);
    Features[ "melspectogram_mean_new" ].append([ melspectrogram_mean_feature(audio, sample_rate ), quality]);

    # Features['pncc_simple_mean'].append([ pncc_simple_mean_feature(audio, sample_rate ), quality]);
    #Features['lpc_simple_mean'].append([lpc_simple_mean_feature(audio, sample_rate), quality]);
    #Features["lpcc_simple_mean"].append([lpcc_simple_mean_feature(audio, sample_rate), quality]);
    # Features['spectral_contrast_mean'].append([spectral_contrast_mean_feature(audio, sample_rate), quality]);
    # Features["spectral_centroid_mean"].append([ spectral_centroid_mean_feature(audio, sample_rate ), quality]);

print("Feature generation phase complete")
end = time.time()
print((end-st)/len(Files))
# Out:
# file no: 0
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/3.21_audio.home_video_8_4.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# 0 data files have been read
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 1
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.24_audio.tie_tut_1_9.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.23_audio.___59_____19.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 3
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/3.96_audio.dive_10.wav
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/spectrum.py:257: UserWarning: n_fft=1024 is too large for input signal of length=949
#   warnings.warn(
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 4
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.24_audio.train_org4.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 5
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.61_audio.___70_____ps.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 6
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/2.19_audio.___4_____21.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 7
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/3.88_audio.___66_____ps.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 8
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.19_audio.implicitDist___420____.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 9
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.76_audio.animation_1_6.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 10
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/3.01_audio.nature_112_10.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 11
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.96_audio.chair_basketball_4.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 12
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.84_audio.___29____.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 13
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/3.20_audio.walkway_1_5.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 14
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.00_audio.news_2_7.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 15
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/3.48_audio.nature_5_3.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 16
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.92_audio.music_22_1.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 17
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.81_audio.boy_dance_org3_1.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 18
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/2.69_audio.84Output___30____.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 19
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.72_audio.street_dance_2_3.wav
# [src/libmpg123/layer3.c:INT123_do_layer3():1841] error: dequantization failed!
# [src/libmpg123/layer3.c:INT123_do_layer3():1801] error: dequantization failed!
# [src/libmpg123/layer3.c:INT123_do_layer3():1841] error: dequantization failed!
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 20
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/2.38_audio.boat_1_3.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 21
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.92_audio.girls_song_org.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 22
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.16_audio.music_41_6.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 23
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/3.07_audio.___23_____ps.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 24
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.16_audio.dance_21_2.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 25
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.41_audio.animation_2_7.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 26
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.92_audio.dance_group_org_1.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 27
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/2.12_audio.nature_org19_2.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 28
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/2.46_audio.40Output___15____.wav
# [src/libmpg123/layer3.c:INT123_do_layer3():1801] error: dequantization failed!
# [src/libmpg123/layer3.c:INT123_do_layer3():1801] error: dequantization failed!
# [src/libmpg123/layer3.c:INT123_do_layer3():1801] error: dequantization failed!
# [src/libmpg123/layer3.c:INT123_do_layer3():1801] error: dequantization failed!
# [src/libmpg123/layer3.c:INT123_do_layer3():1801] error: dequantization failed!
# [src/libmpg123/layer3.c:INT123_do_layer3():1801] error: dequantization failed!
# [src/libmpg123/layer3.c:INT123_do_layer3():1801] error: dequantization failed!
# [src/libmpg123/layer3.c:INT123_do_layer3():1801] error: dequantization failed!
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 29
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.32_audio.childrendance_2_7.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 30
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.80_audio.music_13_8.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 31
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.92_audio.music_63_5.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 32
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.08_audio.train_2_10.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 33
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.84_audio.___51_____19.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 34
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/2.81_audio.chair_basketball_8.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 35
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/3.42_audio.___3_____13.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 36
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.28_audio.basketball_10.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 37
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.32_audio.animation_2_5.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 38
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/2.19_audio.implicitDist___336____.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 39
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.00_audio.interview_22_3.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 40
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/5.00_audio.interview_org41.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 41
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/2.96_audio.street_dance_2_1.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 42
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.80_audio.___60_____20.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 43
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.76_audio.___17____.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 44
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.02_audio.recipe_1_10.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 45
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.46_audio.___57_____11.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 46
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.82_audio.interview_11_1.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 47
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.12_audio.girls_dance1_9.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 48
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/2.20_audio.home_video_5_7.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 49
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/3.69_audio.___39_____13.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 50
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/3.42_audio.implicitDist___125____.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 51
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/2.36_audio.dance_22_1.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 52
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.83_audio.home_video_4_2.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 53
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.57_audio.___8_____ps.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 54
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/2.69_audio.implicitDist___66____.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 55
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/3.32_audio.animation_12_1.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 56
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/3.92_audio.___82_____17.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 57
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.72_audio.friends_1_2.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 58
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/3.64_audio.music_52_2.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 59
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.32_audio.street_dance_org1.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 60
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.16_audio.boxing_2_7.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 61
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.53_audio.___86_____ps.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 62
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/3.53_audio.implicitDist___53____.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 63
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.42_audio.___89_____ps.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 64
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/3.61_audio.implicitDist___439____.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 65
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.92_audio.girl_interview_org_2_2.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 66
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.24_audio.music_22_2.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 67
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.46_audio.implicitDist___101____.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 68
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.88_audio.___85____.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 69
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.21_audio.desert_bike_3.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 70
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/2.20_audio.dance_22_7.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 71
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/3.04_audio.bike_9.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 72
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/2.96_audio.home_video_8_3.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 73
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.65_audio.implicitDist___116____.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 74
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/3.19_audio.implicitDist___220____.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 75
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/2.38_audio.boxing_1_1_13.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 76
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.42_audio.boy_speaking_1_15.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 77
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.58_audio.animation_2_2.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 78
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/5.00_audio.animation_9_8.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 79
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/3.46_audio.guitar_3_12.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 80
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/3.88_audio.bull_1_4.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 81
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/2.32_audio.home_video_7_4.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 82
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.84_audio.music_13_7.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 83
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.23_audio.travel_11_2_15.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 84
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.90_audio.snow_org_2_1.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 85
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.32_audio.music_31_4.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 86
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/2.76_audio.train_org1.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 87
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/2.26_audio.childrendance_2_13.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 88
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.61_audio.___28_____ps.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 89
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.92_audio.___70____.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 90
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.92_audio.guitar_org5.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
# ...
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2042
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/2.68_audio.exercise_1_6.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2043
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.81_audio.boy_dance_org2.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2044
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.16_audio.animation92_8.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2045
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.53_audio.people_rush_1_10.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2046
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/2.12_audio.nature_42_7.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2047
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.07_audio.___87_____ps.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2048
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.57_audio.implicitDist___189____.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2049
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.92_audio.___69____.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2050
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.72_audio.boat_1_5.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2051
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/3.04_audio.field_org_2_2.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2052
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.19_audio.interview_41_13.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2053
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.76_audio.girls_song_1.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2054
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.30_audio.___82_____21.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2055
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.30_audio.boy_dance_2_1_15.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2056
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/2.07_audio.___32_____12.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2057
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/5.00_audio.music_21_6.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2058
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/3.14_audio.street_show_1_1.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2059
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/2.40_audio.nature_13_9.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2060
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/2.57_audio.___3_____20.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2061
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/3.96_audio.___9_____20.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2062
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/3.42_audio.dive_3.wav
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2063
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.24_audio.childrendance_2_4.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2064
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.23_audio.___96____.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2065
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.41_audio.dance_org21.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2066
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/2.53_audio.95Output___30____.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2067
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.19_audio._df____6____.wav
# [src/libmpg123/layer3.c:INT123_do_layer3():1801] error: dequantization failed!
# [src/libmpg123/layer3.c:INT123_do_layer3():1801] error: dequantization failed!
# [src/libmpg123/layer3.c:INT123_do_layer3():1841] error: dequantization failed!
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2068
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.19_audio.implicitDist___412____.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2069
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.38_audio.___100____.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2070
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.84_audio.song_org_1.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2071
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/4.46_audio.___80_____ps.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2072
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/3.96_audio.travel_org13_2.wav
# size of mfcc_simple_mean_feature (40,)
# /tmp/ipykernel_49108/3355741547.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio,sample_rate = librosa.load(file_name)
# /home/ashutosh/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2073
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/1.46_audio.___74_____20.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# file no: 2074
# file_name /home/ashutosh/Desktop/ugmqa_project/DatabaseDistorted/tii_is_changed_mos1/2.76_audio.implicitDist___74____.wav
# size of mfcc_simple_mean_feature (40,)
# size of chroma_cqt_simple_mean_feature (12,)
# size of melspectrogram_mean_feature (128,)
# Feature generation phase complete
# 0.24834931614887285

# %%
#run

feature_names=["mfcc_simple_mean_new", "chroma_cqt_simple_mean_new","melspectogram_mean_new"]
for fn in feature_names:
   print(fn)
   print(len(Features[fn]))
   #print(Features[fn])
# Out:
# mfcc_simple_mean_new
# 2075
# chroma_cqt_simple_mean_new
# 2075
# melspectogram_mean_new
# 2075

# %%
print(Features["spectral_centroid_mean"])
# Out:
# []

# %%
#run
from pathlib import Path  
feature_storage_folder = "./DatabaseDistorted/final_tii_all_finaldata/"+'features/';

# fn= 'melspectogram_mean_new';
# fn= "chroma_cqt_simple_mean_new";
# fn= "mfcc_simple_mean_new";
fn= "spectral_centroid_mean";

extracted_features_df=pd.DataFrame(Features[fn],columns=['feature','class'])
print(extracted_features_df.feature[1])

# del Features[fn]

#print(extracted_features_df.head(10))

feature_list = extracted_features_df['feature'].tolist()
class_list = extracted_features_df['class'].tolist()

new_df = pd.DataFrame(feature_list)
new_df['class'] = class_list
#print(new_df.head(10))

feature_filepath=Path(feature_storage_folder+fn+"dm_2075.csv")  # change 998 to length of the data set just to differetiate feature according to the dataset
feature_filepath.parent.mkdir(parents=True, exist_ok=True)  
new_df.to_csv(feature_filepath) 
print(fn , " csv writing complete")
# Out:
# Series([], Name: feature, dtype: object)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/pandas/core/indexes/range.py:345, in RangeIndex.get_loc(self, key)
#     344 try:
# --> 345     return self._range.index(new_key)
#     346 except ValueError as err:
#
# ValueError: 1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /home/ashutosh/Desktop/ugmqa_project/dm_features (3).ipynb Cell 13 line 1
#      <a href='vscode-notebook-cell:/home/ashutosh/Desktop/ugmqa_project/dm_features%20%283%29.ipynb#X15sZmlsZQ%3D%3D?line=9'>10</a> extracted_features_df=pd.DataFrame(Features[fn],columns=['feature','class'])
#      <a href='vscode-notebook-cell:/home/ashutosh/Desktop/ugmqa_project/dm_features%20%283%29.ipynb#X15sZmlsZQ%3D%3D?line=10'>11</a> print(extracted_features_df.feature)
# ---> <a href='vscode-notebook-cell:/home/ashutosh/Desktop/ugmqa_project/dm_features%20%283%29.ipynb#X15sZmlsZQ%3D%3D?line=11'>12</a> print(extracted_features_df.feature[1])
#      <a href='vscode-notebook-cell:/home/ashutosh/Desktop/ugmqa_project/dm_features%20%283%29.ipynb#X15sZmlsZQ%3D%3D?line=13'>14</a> # del Features[fn]
#      <a href='vscode-notebook-cell:/home/ashutosh/Desktop/ugmqa_project/dm_features%20%283%29.ipynb#X15sZmlsZQ%3D%3D?line=14'>15</a>
#      <a href='vscode-notebook-cell:/home/ashutosh/Desktop/ugmqa_project/dm_features%20%283%29.ipynb#X15sZmlsZQ%3D%3D?line=15'>16</a> #print(extracted_features_df.head(10))
#      <a href='vscode-notebook-cell:/home/ashutosh/Desktop/ugmqa_project/dm_features%20%283%29.ipynb#X15sZmlsZQ%3D%3D?line=17'>18</a> feature_list = extracted_features_df['feature'].tolist()
#
# File ~/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/pandas/core/series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/pandas/core/series.py:1116, in Series._get_value(self, label, takeable)
#    1113     return self._values[label]
#    1115 # Similar to Index.get_value, but we do not fall back to positional
# -> 1116 loc = self.index.get_loc(label)
#    1118 if is_integer(loc):
#    1119     return self._values[loc]
#
# File ~/Desktop/ugmqa_project/venv/lib/python3.8/site-packages/pandas/core/indexes/range.py:347, in RangeIndex.get_loc(self, key)
#     345         return self._range.index(new_key)
#     346     except ValueError as err:
# --> 347         raise KeyError(key) from err
#     348 if isinstance(key, Hashable):
#     349     raise KeyError(key)
#
# KeyError: 1

# %%
fd1 = pd.read_csv("/content/drive/MyDrive/DatabaseDistorted/final_tii_all_finaldata/features/mfcc_simple_mean_newdm_2075.csv")
print(fd1.shape)
fd1 = fd1.dropna(axis=1)
c = fd1['class']
fd1 = fd1.drop(['Unnamed: 0', 'class'], axis=1)
print(fd1.shape)

# %%
fd2 = pd.read_csv("/content/drive/MyDrive/DatabaseDistorted/final_tii_all_finaldata/features/melspectogram_mean_newdm_2075.csv")
print(fd2.shape)
fd2 = fd2.dropna(axis=1)
c = fd2['class']
fd2 = fd2.drop(['Unnamed: 0', 'class'], axis=1)
print(fd2.shape)

# %%
fd3 = pd.read_csv("/content/drive/MyDrive/DatabaseDistorted/final_tii_all_finaldata/features/chroma_cqt_simple_mean_newdm_2075.csv")
print(fd3.shape)
fd3 = fd3.dropna(axis=1)
c = fd3['class']
fd3 = fd3.drop(['Unnamed: 0', 'class'], axis=1)
# fd2 = fd3.drop(['Unnamed: 0'], axis=1)
print(fd3.shape)

# %%
#the audio clips have different outputs, thus take the minimum length equal to 212 in this case
fd4 = pd.read_csv("/content/drive/MyDrive/DatabaseDistorted/final_tii_all_finaldata/features/spectral_centroid_meandm_2075.csv")
print(fd4.shape)
fd4 = fd4.dropna(axis=1)
c = fd4['class']
fd4 = fd4.drop(['Unnamed: 0', 'class'], axis=1)
print(fd4.shape)

l = [str(i) for i in range(212)]
# print(l)
fd4.columns = l
fd4['class']=c
# fd4.to_csv("/content/drive/MyDrive/DatabaseDistorted/final_tii_all_finaldata/features/spectral_centroid_meandm_2075_200.csv")

# %%
# fd2 = pd.read_csv("/content/drive/MyDrive/DatabaseDistorted/final_tii_all_finaldata/features/dm_2075_concatrnated3.csv")

# c = fd2['class']
# fd2 = fd2.drop(['Unnamed: 0', 'class'], axis=1)

finaldf = pd.concat([fd1, fd2, fd3,fd4], axis=1)
print(finaldf.shape)
finaldf = finaldf.drop([ 'class'], axis=1)
print(finaldf.shape)

# l = [str(i) for i in range(180)]
l = [str(i) for i in range(392)]

# print(l)
finaldf.columns = l
finaldf['class']=c
finaldf.to_csv("/content/drive/MyDrive/DatabaseDistorted/final_tii_all_finaldata/features/2075_concatenate_dm_4featu.csv")

# %%
feature_names=["mfcc_simple_mean_new"]
new_df.to_csv(feature_filepath)
